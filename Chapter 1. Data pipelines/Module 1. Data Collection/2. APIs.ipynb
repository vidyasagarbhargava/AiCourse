# %% [markdown]
# # APIs
#
# ## Learning objectives
# - Learn what a REST API is
# - Use REST APIs to obtain data
#
# In the last notebook, we looked at scraping the web to obtain some (housing) data. In many cases, especially when wanting textual data, we may need to resort to scraping the web. However, some websites offer web APIs we may access to pull information from. Information coming from APIs are returned in a structured format, such as JSON.
#
# The word API keeps popping... but what is it? And what is a REST API?
#
# An **API** stands for Application Programmable Interface. When we are writing a program/code, we would often need to interface with other people's code (e.g. a library). An API defines the rules we need to follow to talk to the code (e.g. function names).
#
# A **REST API** allows communication over HTTP. The client sends a request, and the server receives a response. Requests will take on one four following types: GET, PUT, POST, and DELETE. Most related to pulling data from other services (via APIs) is **GET**. As the name implies, this is the HTTP Method we use when we want to request some data.
#
# **So how do we request data?**
# Well, we need a place to request data from, and this comes in the form of an endpoint URL. An endpoint URL usually looks something along these lines:
#
# ![](images/api_url_structure.png)
#
# Let's visit the github API endpoint to see what the **response** is: https://api.github.com/users/ai-core/repos?sort=pushed&direction=desc
#
# As we can see, the response from calling the Github API is a JSON object. However, this doesn't necessarily have to be the case - the developer who coded the API could have allowed for any file format to be returned (XML, CSV, Images etc.). For gathering data through APIs, JSON is typically the easiest to work with, so where possible, we should favour this.

# %% [markdown]
# ### HTTP Codes
# <img src="https://infidigit.b-cdn.net/wp-content/uploads/2019/12/20191227_012601_0000.png" style="width: 350px"/>

# %% [markdown]
# Read the docs! https://api.stackexchange.com/docs

# %% [markdown]
# Let's collect data from StackExchange's API. Here we'll be working in a slightly roundabout fashion to pull the data we want from their API. This is for teaching purposes, so we can understand the structure of JSON, and for you to get some hands on experience with using a REST API.
#
# We'll be collecting the body/contents of questions posted on StackOverflow. To do this, we'll first pull some posts within a date range. If the type of the post is a question, we'll make another API request to StackExchange's questions endpoint to pull the body of the question.

# %%
import requests
# api key
ENDPOINT = "https://api.stackexchange.com"
POSTS = "/2.2/posts?fromdate=1596240000&todate=1596585600&order=desc&sort=activity&site=stackoverflow"
r = requests.get(ENDPOINT+POSTS)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'items': [{'owner': {'reputation': 1,
#     'user_id': 11928859,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-B8_RR_3pH68/AAAAAAAAAAI/AAAAAAAAZfk/G94LtpADtDY/photo.jpg?sz=128',
#     'display_name': 'Alex',
#     'link': 'https://stackoverflow.com/users/11928859/alex'},
#    'score': 0,
#    'last_edit_date': 1597083205,
#    'last_activity_date': 1598692989,
#    'creation_date': 1596568527,
#    'post_type': 'question',
#    'post_id': 63253665,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63253665'},
#   {'owner': {'reputation': 187,
#     'user_id': 1593239,
#     'user_type': 'registered',
#     'accept_rate': 0,
#     'profile_image': 'https://www.gravatar.com/avatar/b09188488f8c6d536c02004e8f12a2b0?s=128&d=identicon&r=PG',
#     'display_name': 'Ori5678',
#     'link': 'https://stackoverflow.com/users/1593239/ori5678'},
#    'score': -1,
#    'last_activity_date': 1598690116,
#    'creation_date': 1596541863,
#    'post_type': 'question',
#    'post_id': 63246287,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63246287'},
#   {'owner': {'reputation': 23,
#     'user_id': 9387989,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6992bd12fd16707c953e1f3408c0db9e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Pacin',
#     'link': 'https://stackoverflow.com/users/9387989/pacin'},
#    'score': 0,
#    'last_edit_date': 1597327513,
#    'last_activity_date': 1598689616,
#    'creation_date': 1596392148,
#    'post_type': 'question',
#    'post_id': 63219539,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63219539'},
#   {'owner': {'reputation': 3,
#     'user_id': 14042405,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/--W_61BjwJdg/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckqBcI8OBw-w0q6DR3nDY7P--jaWA/photo.jpg?sz=128',
#     'display_name': 'Inaylak',
#     'link': 'https://stackoverflow.com/users/14042405/inaylak'},
#    'score': 0,
#    'last_edit_date': 1596500448,
#    'last_activity_date': 1598688688,
#    'creation_date': 1596500065,
#    'post_type': 'question',
#    'post_id': 63238578,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63238578'},
#   {'owner': {'reputation': 485,
#     'user_id': 3057372,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://www.gravatar.com/avatar/adfca228e6508de40e17a5d4cdeadd72?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'to_sam',
#     'link': 'https://stackoverflow.com/users/3057372/to-sam'},
#    'score': 3,
#    'last_activity_date': 1598688599,
#    'creation_date': 1596399158,
#    'post_type': 'question',
#    'post_id': 63220580,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63220580'},
#   {'owner': {'reputation': 29,
#     'user_id': 8175310,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5652884b663ab817644bfc921a33b730?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Syafil',
#     'link': 'https://stackoverflow.com/users/8175310/syafil'},
#    'score': 0,
#    'last_edit_date': 1598687437,
#    'last_activity_date': 1598687437,
#    'creation_date': 1596470276,
#    'post_type': 'question',
#    'post_id': 63232840,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63232840'},
#   {'owner': {'reputation': 55,
#     'user_id': 9692966,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/779bed21ee1f419c8e740d01671c2b95?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Nigel Ng',
#     'link': 'https://stackoverflow.com/users/9692966/nigel-ng'},
#    'score': -2,
#    'last_edit_date': 1598686623,
#    'last_activity_date': 1598686623,
#    'creation_date': 1596294535,
#    'post_type': 'question',
#    'post_id': 63206717,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63206717'},
#   {'owner': {'reputation': 5445,
#     'user_id': 2298336,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d15f6825d09bb820ab62dcd3174723b1?s=128&d=identicon&r=PG',
#     'display_name': 'pdw',
#     'link': 'https://stackoverflow.com/users/2298336/pdw'},
#    'score': 1,
#    'last_edit_date': 1598685559,
#    'last_activity_date': 1598685559,
#    'creation_date': 1596472462,
#    'post_type': 'answer',
#    'post_id': 63233379,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63233379'},
#   {'owner': {'reputation': 3235,
#     'user_id': 3792482,
#     'user_type': 'registered',
#     'accept_rate': 43,
#     'profile_image': 'https://graph.facebook.com/100000271181489/picture?type=large',
#     'display_name': 'phongyewtong',
#     'link': 'https://stackoverflow.com/users/3792482/phongyewtong'},
#    'score': 0,
#    'last_activity_date': 1598684249,
#    'creation_date': 1596474262,
#    'post_type': 'question',
#    'post_id': 63233868,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63233868'},
#   {'owner': {'reputation': 114,
#     'user_id': 6386213,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7a5217302fc3f828bc8cde38b0953cdb?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Bhagyesh',
#     'link': 'https://stackoverflow.com/users/6386213/bhagyesh'},
#    'score': 2,
#    'last_activity_date': 1598678989,
#    'creation_date': 1596534137,
#    'post_type': 'question',
#    'post_id': 63244145,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63244145'},
#   {'owner': {'reputation': 3,
#     'user_id': 13512940,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1f703b1ff52125d8b240bd3e40d7d90b?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Mohiuddin',
#     'link': 'https://stackoverflow.com/users/13512940/mohiuddin'},
#    'score': -2,
#    'last_edit_date': 1598678708,
#    'last_activity_date': 1598678708,
#    'creation_date': 1596391700,
#    'post_type': 'question',
#    'post_id': 63219464,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63219464'},
#   {'owner': {'reputation': 1205,
#     'user_id': 9937309,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-cALD0EpWqls/AAAAAAAAAAI/AAAAAAAAARs/RaQzFwo3fzo/photo.jpg?sz=128',
#     'display_name': 'Shahzad Akram',
#     'link': 'https://stackoverflow.com/users/9937309/shahzad-akram'},
#    'score': 0,
#    'last_edit_date': 1596343339,
#    'last_activity_date': 1598668245,
#    'creation_date': 1596343067,
#    'post_type': 'question',
#    'post_id': 63212436,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63212436'},
#   {'owner': {'reputation': 1,
#     'user_id': 14045261,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1710119f4ed4d0b27c7844276ece44e3?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Artee Rawat',
#     'link': 'https://stackoverflow.com/users/14045261/artee-rawat'},
#    'score': 0,
#    'last_edit_date': 1597012647,
#    'last_activity_date': 1598647698,
#    'creation_date': 1596507833,
#    'post_type': 'question',
#    'post_id': 63239370,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63239370'},
#   {'owner': {'reputation': 57,
#     'user_id': 13752749,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c48fb394fde5579e2a0a173cedb7fc9a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Kevin Greetham',
#     'link': 'https://stackoverflow.com/users/13752749/kevin-greetham'},
#    'score': 2,
#    'last_activity_date': 1598641849,
#    'creation_date': 1596426929,
#    'post_type': 'question',
#    'post_id': 63223506,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63223506'},
#   {'owner': {'reputation': 2453,
#     'user_id': 988591,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://www.gravatar.com/avatar/248624b122eb5cc3748ee7131fc0b3f4?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'jj_',
#     'link': 'https://stackoverflow.com/users/988591/jj'},
#    'score': -1,
#    'last_edit_date': 1598635046,
#    'last_activity_date': 1598635046,
#    'creation_date': 1596483298,
#    'post_type': 'answer',
#    'post_id': 63235864,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63235864'},
#   {'owner': {'reputation': 53,
#     'user_id': 12539821,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/469302307149059d752c322528991207?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Alon123',
#     'link': 'https://stackoverflow.com/users/12539821/alon123'},
#    'score': 0,
#    'last_edit_date': 1598363551,
#    'last_activity_date': 1598633432,
#    'creation_date': 1596454496,
#    'post_type': 'question',
#    'post_id': 63228690,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63228690'},
#   {'owner': {'reputation': 13,
#     'user_id': 3011085,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0670248e6ff8f914b0411ba6a9929a27?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'lhag',
#     'link': 'https://stackoverflow.com/users/3011085/lhag'},
#    'score': 0,
#    'last_activity_date': 1598633113,
#    'creation_date': 1596299997,
#    'post_type': 'question',
#    'post_id': 63207612,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63207612'},
#   {'owner': {'reputation': 57,
#     'user_id': 8843561,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://www.gravatar.com/avatar/74dfb98a6b46f9a0c6820a6f1fee3d26?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'devesh',
#     'link': 'https://stackoverflow.com/users/8843561/devesh'},
#    'score': 0,
#    'last_activity_date': 1598631205,
#    'creation_date': 1596262871,
#    'post_type': 'question',
#    'post_id': 63202408,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63202408'},
#   {'owner': {'reputation': 23,
#     'user_id': 9604176,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-LZE9ZOSGnrg/AAAAAAAAAAI/AAAAAAAAHcY/oNJ94henVAM/photo.jpg?sz=128',
#     'display_name': 'Yovan Gaming',
#     'link': 'https://stackoverflow.com/users/9604176/yovan-gaming'},
#    'score': 1,
#    'last_edit_date': 1596483333,
#    'last_activity_date': 1598631064,
#    'creation_date': 1596479707,
#    'post_type': 'question',
#    'post_id': 63235072,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63235072'},
#   {'owner': {'reputation': 4774,
#     'user_id': 5362583,
#     'user_type': 'registered',
#     'accept_rate': 0,
#     'profile_image': 'https://i.stack.imgur.com/XYISG.jpg?s=128&g=1',
#     'display_name': 'Alok',
#     'link': 'https://stackoverflow.com/users/5362583/alok'},
#    'score': 1,
#    'last_edit_date': 1598631064,
#    'last_activity_date': 1598631064,
#    'creation_date': 1596482159,
#    'post_type': 'answer',
#    'post_id': 63235599,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63235599'},
#   {'owner': {'reputation': 3,
#     'user_id': 5648016,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/fdd1c1c3a27598f456dd23459c6ee026?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Beau2000',
#     'link': 'https://stackoverflow.com/users/5648016/beau2000'},
#    'score': 0,
#    'last_edit_date': 1598631037,
#    'last_activity_date': 1598631037,
#    'creation_date': 1596513357,
#    'post_type': 'question',
#    'post_id': 63240060,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63240060'},
#   {'owner': {'reputation': 89,
#     'user_id': 8748045,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2800342164c0b772f96e578ff32f9102?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ole',
#     'link': 'https://stackoverflow.com/users/8748045/ole'},
#    'score': 0,
#    'last_edit_date': 1598631018,
#    'last_activity_date': 1598631018,
#    'creation_date': 1596568974,
#    'post_type': 'question',
#    'post_id': 63253776,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63253776'},
#   {'owner': {'reputation': 5,
#     'user_id': 14046361,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gj8he9O4tlTDhpanSgHpYznqWFDWRt37geOhR9qfg=k-s128',
#     'display_name': 'saikumar voruganti',
#     'link': 'https://stackoverflow.com/users/14046361/saikumar-voruganti'},
#    'score': 0,
#    'last_edit_date': 1598626924,
#    'last_activity_date': 1598626924,
#    'creation_date': 1596525936,
#    'post_type': 'question',
#    'post_id': 63242014,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63242014'},
#   {'owner': {'reputation': 229,
#     'user_id': 13458882,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-NeIT50aX_fw/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJOea_cg3fhsaJ9qIOgcOrFUDjjslg/photo.jpg?sz=128',
#     'display_name': 'Fenzox',
#     'link': 'https://stackoverflow.com/users/13458882/fenzox'},
#    'score': 0,
#    'last_edit_date': 1598626044,
#    'last_activity_date': 1598626044,
#    'creation_date': 1596277274,
#    'post_type': 'answer',
#    'post_id': 63204140,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63204140'},
#   {'owner': {'reputation': 179,
#     'user_id': 13351790,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5ef92a6d6b39d338fc1b348e3a97b192?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Pj30',
#     'link': 'https://stackoverflow.com/users/13351790/pj30'},
#    'score': 1,
#    'last_edit_date': 1598619715,
#    'last_activity_date': 1598619715,
#    'creation_date': 1596297893,
#    'post_type': 'question',
#    'post_id': 63207272,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63207272'},
#   {'owner': {'reputation': 39,
#     'user_id': 11591742,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-Ghh5HpPmFxQ/AAAAAAAAAAI/AAAAAAAAAA0/VBl8XL1JSlA/photo.jpg?sz=128',
#     'display_name': 'jaymzleutz',
#     'link': 'https://stackoverflow.com/users/11591742/jaymzleutz'},
#    'score': 1,
#    'last_edit_date': 1596489256,
#    'last_activity_date': 1598616755,
#    'creation_date': 1596487770,
#    'post_type': 'question',
#    'post_id': 63236768,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63236768'},
#   {'owner': {'reputation': 9245,
#     'user_id': 7175713,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/JJ3Jk.jpg?s=128&g=1',
#     'display_name': 'sammywemmy',
#     'link': 'https://stackoverflow.com/users/7175713/sammywemmy'},
#    'score': 1,
#    'last_edit_date': 1598616755,
#    'last_activity_date': 1598616755,
#    'creation_date': 1596489306,
#    'post_type': 'answer',
#    'post_id': 63237055,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63237055'},
#   {'owner': {'reputation': 81,
#     'user_id': 10295381,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/fcbe4d7096b0e6c6a5015f15e7d8fa1e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'PeppaCat',
#     'link': 'https://stackoverflow.com/users/10295381/peppacat'},
#    'score': 0,
#    'last_activity_date': 1598611676,
#    'creation_date': 1596354836,
#    'post_type': 'question',
#    'post_id': 63213666,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63213666'},
#   {'owner': {'reputation': 1700,
#     'user_id': 7103882,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/1WwhK.jpg?s=128&g=1',
#     'display_name': 'Codemaker',
#     'link': 'https://stackoverflow.com/users/7103882/codemaker'},
#    'score': 0,
#    'last_edit_date': 1598610898,
#    'last_activity_date': 1598610898,
#    'creation_date': 1596442867,
#    'post_type': 'answer',
#    'post_id': 63226000,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63226000'},
#   {'owner': {'reputation': 185,
#     'user_id': 9028098,
#     'user_type': 'registered',
#     'accept_rate': 71,
#     'profile_image': 'https://www.gravatar.com/avatar/c6998a17853d32e83c5f8f7eec078b2e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Ofek Pintok',
#     'link': 'https://stackoverflow.com/users/9028098/ofek-pintok'},
#    'score': 0,
#    'last_activity_date': 1598607710,
#    'creation_date': 1596543226,
#    'post_type': 'question',
#    'post_id': 63246656,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63246656'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 295}

# %%
def get_questions(items_object):
    data = {"display_name": [], "profile_image_url": [], "post_id": [], "post_contents": []}
    
    ## Loop over the items object. For the relevant fields in the 'data' variable defined above,
    ## Populate those fields IF the type of the post is a question.
    ## If the type of a post is a question, additionally a request to the relevent API method to obtain the question body
    ## READ READ READ the documentation (or Google it 🙄) to find out how to do so
    ## The question body should be populated in the 'post_contents' field
    ## Return the data object

# %%
import pprint

questions = get_questions(r.json()["items"])
pprint.pprint(questions)

# %%
for dn, piu, pi, pc in zip(questions["display_name"], questions["profile_image_url"], questions["post_id"], questions["post_contents"]):
    print("Display Name:", dn)
    print("Profile Image URL:", piu)
    print("Post ID:", pi)
    print("Post Body:", pc)
    print()
