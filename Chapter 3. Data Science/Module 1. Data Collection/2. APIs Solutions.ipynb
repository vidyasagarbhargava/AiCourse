# %% [markdown]
# # APIs
#
# ## Learning objectives:
# - Learn what a REST API is
# - Use REST APIs to obtain data
#
# In the last notebook, we looked at scraping the web to obtain some (housing) data. In many cases, especially when wanting textual data, we may need to resort to scraping the web. However, some websites offer web APIs we may access to pull information from. Information coming from APIs are returned in a structured format, such as JSON.
#
# The word API keeps popping... but what is it? And what is a REST API?
#
# An **API** stands for Application Programmable Interface. When we are writing a program/code, we would often need to interface with other people's code (e.g. a library). An API defines the rules we need to follow to talk to the code (e.g. function names).
#
# A **REST API** allows communication over HTTP. The client sends a request, and the server receives a response. Requests will take on one four following types: GET, PUT, POST, and DELETE. Most related to pulling data from other services (via APIs) is **GET**. As the name implies, this is the HTTP Method we use when we want to request some data.
#
# **So how do we request data?**
# Well, we need a place to request data from, and this comes in the form of an endpoint URL. An endpoint URL usually looks something along these lines:
#
# ![](images/api_url_structure.png)
#
# Let's visit the github API endpoint to see what the **response** is: https://api.github.com/users/ai-core/repos?sort=pushed&direction=desc
#
# As we can see, the response from calling the Github API is a JSON object. However, this doesn't necessarily have to be the case - the developer who coded the API could have allowed for any file format to be returned (XML, CSV, Images etc.). For gathering data through APIs, JSON is typically the easiest to work with, so where possible, we should favour this.

# %% [markdown]
# ### HTTP Codes
# <img src="https://infidigit.b-cdn.net/wp-content/uploads/2019/12/20191227_012601_0000.png" style="width: 350px"/>

# %% [markdown]
# Read the docs! https://api.stackexchange.com/docs

# %% [markdown]
# Let's collect data from StackExchange's API. Here we'll be working in a slightly roundabout fashion to pull the data we want from their API. This is for teaching purposes, so we can understand the structure of JSON, and for you to get some hands on experience with using a REST API.
#
# We'll be collecting the body/contents of questions posted on StackOverflow. To do this, we'll first pull some posts within a date range. If the type of the post is a question, we'll make another API request to StackExchange's questions endpoint to pull the body of the question.

# %%
import requests
# api key
ROOT_URL = "https://api.stackexchange.com"
POSTS_ENDPOINT = "/2.2/posts?fromdate=1596240000&todate=1596585600&order=desc&sort=activity&site=stackoverflow"
r = requests.get(ROOT_URL+POSTS_ENDPOINT)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'items': [{'owner': {'reputation': 41,
#     'user_id': 14045196,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b0267f35bc49691febef17386d54728c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Dashing',
#     'link': 'https://stackoverflow.com/users/14045196/dashing'},
#    'score': 4,
#    'last_activity_date': 1597952535,
#    'creation_date': 1596507109,
#    'post_type': 'question',
#    'post_id': 63239300,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63239300'},
#   {'owner': {'reputation': 51204,
#     'user_id': 2864740,
#     'user_type': 'registered',
#     'accept_rate': 78,
#     'profile_image': 'https://www.gravatar.com/avatar/e7a05a144f218bde07b659bc98e1ca7d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user2864740',
#     'link': 'https://stackoverflow.com/users/2864740/user2864740'},
#    'score': 4,
#    'last_edit_date': 1597952535,
#    'last_activity_date': 1597952535,
#    'creation_date': 1596508518,
#    'post_type': 'answer',
#    'post_id': 63239450,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63239450'},
#   {'owner': {'reputation': 1,
#     'user_id': 10938964,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ded581240d45e256d68e6807130c2582?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Liamdale',
#     'link': 'https://stackoverflow.com/users/10938964/liamdale'},
#    'score': 0,
#    'last_edit_date': 1597951894,
#    'last_activity_date': 1597951894,
#    'creation_date': 1596431921,
#    'post_type': 'question',
#    'post_id': 63224104,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63224104'},
#   {'owner': {'reputation': 1206,
#     'user_id': 11220884,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/6wFcg.jpg?s=128&g=1',
#     'display_name': 'Tinu',
#     'link': 'https://stackoverflow.com/users/11220884/tinu'},
#    'score': 6,
#    'last_edit_date': 1597951286,
#    'last_activity_date': 1597951286,
#    'creation_date': 1596437502,
#    'post_type': 'question',
#    'post_id': 63224935,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63224935'},
#   {'owner': {'reputation': 409,
#     'user_id': 11744237,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/dc4c77dd26dded88dd3d196be106cd94?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Uuuuuumm',
#     'link': 'https://stackoverflow.com/users/11744237/uuuuuumm'},
#    'score': 0,
#    'last_edit_date': 1597950474,
#    'last_activity_date': 1597950474,
#    'creation_date': 1596477018,
#    'post_type': 'question',
#    'post_id': 63234496,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63234496'},
#   {'owner': {'reputation': 257,
#     'user_id': 716255,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4057228c332e51257f3041ab597c7c73?s=128&d=identicon&r=PG',
#     'display_name': 'user716255',
#     'link': 'https://stackoverflow.com/users/716255/user716255'},
#    'score': 0,
#    'last_edit_date': 1597949574,
#    'last_activity_date': 1597949574,
#    'creation_date': 1596491160,
#    'post_type': 'question',
#    'post_id': 63237383,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63237383'},
#   {'owner': {'reputation': 43,
#     'user_id': 10862759,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-ebmDzzMuzRQ/AAAAAAAAAAI/AAAAAAAABNM/OuhnEXZ97-k/photo.jpg?sz=128',
#     'display_name': 'Kevko',
#     'link': 'https://stackoverflow.com/users/10862759/kevko'},
#    'score': -3,
#    'last_activity_date': 1597944971,
#    'creation_date': 1596480420,
#    'post_type': 'question',
#    'post_id': 63235230,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63235230'},
#   {'owner': {'reputation': 318,
#     'user_id': 11321411,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/aff4c81788c8de39de6e8144d5695137?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'aDeveloper',
#     'link': 'https://stackoverflow.com/users/11321411/adeveloper'},
#    'score': 1,
#    'last_edit_date': 1597944971,
#    'last_activity_date': 1597944971,
#    'creation_date': 1596481367,
#    'post_type': 'answer',
#    'post_id': 63235438,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63235438'},
#   {'owner': {'reputation': 360,
#     'user_id': 1046364,
#     'user_type': 'registered',
#     'accept_rate': 45,
#     'profile_image': 'https://www.gravatar.com/avatar/3aae252b0cef6df16e7b8c2020b050da?s=128&d=identicon&r=PG',
#     'display_name': 'nikolifish',
#     'link': 'https://stackoverflow.com/users/1046364/nikolifish'},
#    'score': 0,
#    'last_edit_date': 1596903836,
#    'last_activity_date': 1597944412,
#    'creation_date': 1596473720,
#    'post_type': 'question',
#    'post_id': 63233712,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63233712'},
#   {'owner': {'reputation': 503,
#     'user_id': 3192775,
#     'user_type': 'registered',
#     'accept_rate': 33,
#     'profile_image': 'https://i.stack.imgur.com/8htyd.jpg?s=128&g=1',
#     'display_name': 'Tim',
#     'link': 'https://stackoverflow.com/users/3192775/tim'},
#    'score': 5,
#    'last_edit_date': 1597163189,
#    'last_activity_date': 1597938929,
#    'creation_date': 1596481418,
#    'post_type': 'question',
#    'post_id': 63235455,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63235455'},
#   {'owner': {'reputation': 3228,
#     'user_id': 2435154,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://i.stack.imgur.com/2MOY0.png?s=128&g=1',
#     'display_name': 'Tulon',
#     'link': 'https://stackoverflow.com/users/2435154/tulon'},
#    'score': 0,
#    'last_edit_date': 1597937287,
#    'last_activity_date': 1597937287,
#    'creation_date': 1596492453,
#    'post_type': 'question',
#    'post_id': 63237587,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63237587'},
#   {'owner': {'reputation': 639,
#     'user_id': 2776727,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/c38f6255df694b842b5f0b588946beee?s=128&d=identicon&r=PG',
#     'display_name': 'Andreas',
#     'link': 'https://stackoverflow.com/users/2776727/andreas'},
#    'score': 0,
#    'last_edit_date': 1597936847,
#    'last_activity_date': 1597936847,
#    'creation_date': 1596534912,
#    'post_type': 'question',
#    'post_id': 63244392,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63244392'},
#   {'owner': {'reputation': 690,
#     'user_id': 8965420,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-9YrXTDQImsU/AAAAAAAAAAI/AAAAAAAAELQ/WJsZP3aPFDM/photo.jpg?sz=128',
#     'display_name': 'Ahmed Ghrib',
#     'link': 'https://stackoverflow.com/users/8965420/ahmed-ghrib'},
#    'score': 0,
#    'last_activity_date': 1597935915,
#    'creation_date': 1596553413,
#    'post_type': 'question',
#    'post_id': 63249690,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63249690'},
#   {'owner': {'reputation': 13,
#     'user_id': 13629957,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-BiwcTfc3e-w/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmdeMfy8TRUKoMkp0ka-Oa2Zotk3A/photo.jpg?sz=128',
#     'display_name': 'Siddhesh DilipKumar',
#     'link': 'https://stackoverflow.com/users/13629957/siddhesh-dilipkumar'},
#    'score': 0,
#    'last_edit_date': 1597933279,
#    'last_activity_date': 1597933279,
#    'creation_date': 1596510348,
#    'post_type': 'question',
#    'post_id': 63239647,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63239647'},
#   {'owner': {'reputation': 13,
#     'user_id': 13734736,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3bc500cf9588bddbdd4fa52fe08ad7cc?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Jinkinson',
#     'link': 'https://stackoverflow.com/users/13734736/jinkinson'},
#    'score': 0,
#    'last_edit_date': 1597933274,
#    'last_activity_date': 1597933274,
#    'creation_date': 1596475750,
#    'post_type': 'question',
#    'post_id': 63234238,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63234238'},
#   {'owner': {'reputation': 99,
#     'user_id': 4069898,
#     'user_type': 'registered',
#     'accept_rate': 0,
#     'profile_image': 'https://www.gravatar.com/avatar/88f01fcad07a39cf41af8ac708b2c98d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Jag99',
#     'link': 'https://stackoverflow.com/users/4069898/jag99'},
#    'score': -1,
#    'last_edit_date': 1597932740,
#    'last_activity_date': 1597932740,
#    'creation_date': 1596443699,
#    'post_type': 'question',
#    'post_id': 63226191,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63226191'},
#   {'owner': {'reputation': 314,
#     'user_id': 2642383,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/5iI1f.jpg?s=128&g=1',
#     'display_name': 'Chris Karpyszyn',
#     'link': 'https://stackoverflow.com/users/2642383/chris-karpyszyn'},
#    'score': 0,
#    'last_edit_date': 1597930067,
#    'last_activity_date': 1597930067,
#    'creation_date': 1596465347,
#    'post_type': 'answer',
#    'post_id': 63231453,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63231453'},
#   {'owner': {'reputation': 95,
#     'user_id': 4362370,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/546533d812c53dc1f380e8a0c7f62da6?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'JFortYork',
#     'link': 'https://stackoverflow.com/users/4362370/jfortyork'},
#    'score': 1,
#    'last_edit_date': 1596630794,
#    'last_activity_date': 1597929122,
#    'creation_date': 1596570111,
#    'post_type': 'question',
#    'post_id': 63254016,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63254016'},
#   {'owner': {'reputation': 69,
#     'user_id': 8298248,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/oVKxE.jpg?s=128&g=1',
#     'display_name': 'bhanu',
#     'link': 'https://stackoverflow.com/users/8298248/bhanu'},
#    'score': 1,
#    'last_edit_date': 1597927899,
#    'last_activity_date': 1597927899,
#    'creation_date': 1596575104,
#    'post_type': 'answer',
#    'post_id': 63255029,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/63255029'},
#   {'owner': {'reputation': 1,
#     'user_id': 14037217,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b94724b49fe1a75a1f6419e6386cb07e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Rahul',
#     'link': 'https://stackoverflow.com/users/14037217/rahul'},
#    'score': 0,
#    'last_edit_date': 1596601544,
#    'last_activity_date': 1597926630,
#    'creation_date': 1596385582,
#    'post_type': 'question',
#    'post_id': 63218398,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63218398'},
#   {'owner': {'reputation': 1,
#     'user_id': 14048024,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a70a743a77b6a013c20503764c75ae9c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Sabahat',
#     'link': 'https://stackoverflow.com/users/14048024/sabahat'},
#    'score': 0,
#    'last_activity_date': 1597924941,
#    'creation_date': 1596546596,
#    'post_type': 'question',
#    'post_id': 63247616,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63247616'},
#   {'owner': {'reputation': 3,
#     'user_id': 9756109,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/eb5d828cfc565a7a8645a987031169fc?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Saad Ashraf',
#     'link': 'https://stackoverflow.com/users/9756109/saad-ashraf'},
#    'score': 0,
#    'last_activity_date': 1597924298,
#    'creation_date': 1596571065,
#    'post_type': 'question',
#    'post_id': 63254234,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63254234'},
#   {'owner': {'reputation': 13,
#     'user_id': 13693060,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d93bcd74931c7cd8fc7e7246e9dab318?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Somanden',
#     'link': 'https://stackoverflow.com/users/13693060/somanden'},
#    'score': 0,
#    'last_edit_date': 1597923467,
#    'last_activity_date': 1597923467,
#    'creation_date': 1596287537,
#    'post_type': 'question',
#    'post_id': 63205581,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63205581'},
#   {'owner': {'reputation': 39,
#     'user_id': 4244216,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-LdtSZorvquw/AAAAAAAAAAI/AAAAAAAAAwg/NFbU2DLYCCs/photo.jpg?sz=128',
#     'display_name': 'Gaurav Chaudhary',
#     'link': 'https://stackoverflow.com/users/4244216/gaurav-chaudhary'},
#    'score': 1,
#    'last_activity_date': 1597922392,
#    'creation_date': 1596433879,
#    'post_type': 'question',
#    'post_id': 63224351,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63224351'},
#   {'owner': {'reputation': 1024,
#     'user_id': 9836706,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/p2ehG.jpg?s=128&g=1',
#     'display_name': 'Francesco Iapicca',
#     'link': 'https://stackoverflow.com/users/9836706/francesco-iapicca'},
#    'score': 0,
#    'last_activity_date': 1597921667,
#    'creation_date': 1596554319,
#    'post_type': 'question',
#    'post_id': 63250005,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63250005'},
#   {'owner': {'reputation': 31,
#     'user_id': 13468914,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gh1ZJ2Zo-I04GdhCw3lWMHMR1oNWr2U8YpOGcCyiA=k-s128',
#     'display_name': 'Pixeel',
#     'link': 'https://stackoverflow.com/users/13468914/pixeel'},
#    'score': 3,
#    'last_edit_date': 1596433866,
#    'last_activity_date': 1597915272,
#    'creation_date': 1596364177,
#    'post_type': 'question',
#    'post_id': 63214920,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63214920'},
#   {'owner': {'reputation': 1,
#     'user_id': 14048857,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GigO0OU1Sfce93c2gyLmtvF4PZkQ8rC09fy-BIYJnA=k-s128',
#     'display_name': 'xuan',
#     'link': 'https://stackoverflow.com/users/14048857/xuan'},
#    'score': 0,
#    'last_edit_date': 1597679974,
#    'last_activity_date': 1597914587,
#    'creation_date': 1596557452,
#    'post_type': 'question',
#    'post_id': 63250880,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63250880'},
#   {'owner': {'reputation': 11,
#     'user_id': 14049315,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bed8d007d46188649af0f2661c9360a6?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'JPV',
#     'link': 'https://stackoverflow.com/users/14049315/jpv'},
#    'score': 1,
#    'last_edit_date': 1597913462,
#    'last_activity_date': 1597913462,
#    'creation_date': 1596559616,
#    'post_type': 'question',
#    'post_id': 63251481,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63251481'},
#   {'owner': {'reputation': 689,
#     'user_id': 2202718,
#     'user_type': 'registered',
#     'accept_rate': 92,
#     'profile_image': 'https://www.gravatar.com/avatar/adabf7f065858c050e95bb5f712b3092?s=128&d=identicon&r=PG',
#     'display_name': 'Trts',
#     'link': 'https://stackoverflow.com/users/2202718/trts'},
#    'score': 0,
#    'last_edit_date': 1597911220,
#    'last_activity_date': 1597911220,
#    'creation_date': 1596565659,
#    'post_type': 'question',
#    'post_id': 63253017,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63253017'},
#   {'owner': {'reputation': 1,
#     'user_id': 14039262,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ggggjq8vCSSAnYgxo1UROzCIujKpwXQWA6L4adsTGo=k-s128',
#     'display_name': 'Jose Maria del Olmo',
#     'link': 'https://stackoverflow.com/users/14039262/jose-maria-del-olmo'},
#    'score': 0,
#    'last_edit_date': 1597909581,
#    'last_activity_date': 1597909581,
#    'creation_date': 1596419140,
#    'post_type': 'question',
#    'post_id': 63222719,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/63222719'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 248}

# %%
def get_questions(items_object):
    data = {"display_name": [], "profile_image_url": [], "post_id": [], "post_contents": []}
    
    ## Loop over the items object. For the relevant fields in the 'data' variable defined above,
    ## Populate those fields IF the type of the post is a question.
    ## If the type of a post is a question, additionally a request to the relevent API method to obtain the question body
    ## READ READ READ the documentation (or Google it 🙄) to find out how to do so
    ## The question body should be populated in the 'post_contents' field
    ## Return the data object
    for item in items_object:
        if item["post_type"] == "question":

            data["display_name"].append(item["owner"]["display_name"])
            data["profile_image_url"].append(item["owner"]["profile_image"])
            data["post_id"].append(item["post_id"])
            
            question_endpoint = "/2.2/questions/{}?order=desc&sort=activity&site=stackoverflow&filter=withbody".format(item["post_id"])
            r = requests.get(ROOT_URL+question_endpoint)
            if r.status_code == 200:
                body = r.json()["items"][0]["body"]
                data["post_contents"].append(body)
        
    return data

# %%
import pprint

questions = get_questions(r.json()["items"])
pprint.pprint(questions)
# Out:
# {'display_name': ['Dashing',
#                   'Liamdale',
#                   'Tinu',
#                   'Uuuuuumm',
#                   'user716255',
#                   'Kevko',
#                   'nikolifish',
#                   'Tim',
#                   'Tulon',
#                   'Andreas',
#                   'Ahmed Ghrib',
#                   'Siddhesh DilipKumar',
#                   'Jinkinson',
#                   'Jag99',
#                   'JFortYork',
#                   'Rahul',
#                   'Sabahat',
#                   'Saad Ashraf',
#                   'Somanden',
#                   'Gaurav Chaudhary',
#                   'Francesco Iapicca',
#                   'Pixeel',
#                   'xuan',
#                   'JPV',
#                   'Trts',
#                   'Jose Maria del Olmo'],
#  'post_contents': ['<p>Swift code</p>\n'
#                    '<pre><code>print(&quot;1&quot;, NSObject() == NSObject())\n'
#                    'print(&quot;2&quot;, ObjectIdentifier(NSObject()) == '
#                    'ObjectIdentifier(NSObject()))\n'
#                    'let object3 = NSObject()\n'
#                    'let object4 = NSObject()\n'
#                    'print(&quot;3&quot;, object3, object4)\n'
#                    'print(&quot;4&quot;, ObjectIdentifier(object3) == '
#                    'ObjectIdentifier(object4))\n'
#                    '</code></pre>\n'
#                    '<p>Console result</p>\n'
#                    '<pre><code>1 false\n'
#                    '2 true\n'
#                    '3 &lt;NSObject: 0x600000d805f0&gt; &lt;NSObject: '
#                    '0x600000d80610&gt;\n'
#                    '4 false\n'
#                    '</code></pre>\n'
#                    '<p>ObjectIdentifier compares instances using their object '
#                    'identifiers and the identical-to operator '
#                    '<code>===</code>. Why NSObject() in print(&quot;1&quot;, '
#                    '...) is two object, but in print(&quot;2&quot;, ...) is '
#                    'same object?</p>\n',
#                    '<p>I am working on an app using python3 and SqlAlchemy for '
#                    'SQLite3 database management.  I have some tables that have '
#                    "a Many to Many relationship.  I've created an association "
#                    'table to handle this relationship.</p>\n'
#                    '<pre><code>Class Machine(Base):\n'
#                    "    __tablename__ 'machine'\n"
#                    '    machine_ID = Column(Integer, primary_key=True)\n'
#                    '    etc...\n'
#                    'Class Options(Base):\n'
#                    "    __tableName__ 'options'\n"
#                    '    options_ID = Column(Integer, primary_key=True)\n'
#                    '    etc...\n'
#                    '\n'
#                    'The association table\n'
#                    '\n'
#                    "Machine_Options = table('machine_options', Base.metadata,\n"
#                    "    Column('machine_FK', Integer, "
#                    "ForeignKey('machine.machine_ID'),\n"
#                    '                                 primary_key=True),\n'
#                    "    Column('options_FK',Integer, "
#                    "ForeignKey('options.options_ID'),\n"
#                    '                                 primary_key=True))\n'
#                    '</code></pre>\n'
#                    '<p>All the items for the Machine and Options are inserted '
#                    'independently.  When I want to associate a machine with an '
#                    'option I use an append query which works very well.</p>\n'
#                    '<p>My problem is when I want to break this association '
#                    'between a machine and an option.  I have tried a direct '
#                    'row deletion from the association table using a FILTER() '
#                    'clause on the machine_FK and the options_FK but SqlAlchemy '
#                    "gives me an error informing me that 'Machine_Options' "
#                    "table has no field 'machine_FK'.\n"
#                    "I have tried to remove the row from 'Machine_Options' "
#                    'indirectly using joins with the machine and options table '
#                    'but received another error that I can not delete or update '
#                    'using joins.</p>\n'
#                    '<p>I am looking for the code to only delete a row from the '
#                    'association table without affecting the original machine '
#                    'or options table.</p>\n'
#                    '<p>So far my internet search has been fruitless.</p>\n',
#                    '<p>When using random forests in <code>R</code> I came '
#                    'across the following situation:</p>\n'
#                    '<pre><code>library(randomForest)\n'
#                    'set.seed(42)\n'
#                    'data(iris)\n'
#                    'rf_noImportance &lt;- '
#                    'randomForest(Species~.,data=iris,ntree=100,importance=F)\n'
#                    'print(table(predict(rf_noImportance),iris$Species))\n'
#                    '</code></pre>\n'
#                    '<p>Output:</p>\n'
#                    '<blockquote>\n'
#                    '<pre><code>            setosa versicolor virginica\n'
#                    ' setosa         50          0         0\n'
#                    ' versicolor      0         47         3\n'
#                    ' virginica       0          3        47\n'
#                    '</code></pre>\n'
#                    '</blockquote>\n'
#                    '<p>and</p>\n'
#                    '<pre><code>library(randomForest)\n'
#                    'set.seed(42)\n'
#                    'data(iris)  \n'
#                    'rf_importance &lt;- '
#                    'randomForest(Species~.,data=iris,ntree=100,importance=T)\n'
#                    'print(table(predict(rf_importance),iris$Species))\n'
#                    '</code></pre>\n'
#                    '<p>Output:</p>\n'
#                    '<blockquote>\n'
#                    '<pre><code>            setosa versicolor virginica\n'
#                    ' setosa         50          0         0\n'
#                    ' versicolor      0         47         4\n'
#                    ' virginica       0          3        46\n'
#                    '</code></pre>\n'
#                    '</blockquote>\n'
#                    '<p>In the first example I set <code>importance = '
#                    'FALSE</code> and in the second example <code>TRUE</code>. '
#                    'From my understanding this should not affect the resulting '
#                    "prediction. There's also no indication for that behavior "
#                    'in the <a '
#                    'href="https://cran.r-project.org/web/packages/randomForest/randomForest.pdf" '
#                    'rel="nofollow noreferrer">documentation</a>.</p>\n'
#                    '<p>According to <a '
#                    'href="https://stats.stackexchange.com/q/219498/264183">this</a> '
#                    'cross-validated post the importance flag should not '
#                    'influence the predictions, but it clearly does in the '
#                    'example above.</p>\n'
#                    '<p>So why is the importance parameter of the '
#                    '<code>randomForest</code> method influencing the '
#                    'performance of the model?</p>\n',
#                    "<p>I am consuming another company's SOAP API via postman "
#                    'and it keeps returning an error</p>\n'
#                    '<p>Based on my research, when people have been getting '
#                    'this error, they are also developing the API and the fix '
#                    'was always a server-side edit. So, I am lead to believe '
#                    'that this error is not my fault.</p>\n'
#                    '<p>I can get other errors if I use incorrect credentials, '
#                    'bad XML formatting, etc. I can successfully use the SOAP '
#                    '&quot;Login&quot; request for this API, but the all the '
#                    'getter SOAP requests for this API throw this same '
#                    'error</p>\n'
#                    "<p>I don't believe this is an account permission error "
#                    'because my I was told by my superiors the account had the '
#                    'permissions required. Is there something I can do on my '
#                    'end to resolve this error?</p>\n'
#                    '<p>My SOAP Body:</p>\n'
#                    '<pre><code>&lt;?xml version=&quot;1.0&quot; '
#                    'encoding=&quot;utf-8&quot; ?&gt;\n'
#                    '&lt;soap:Envelope '
#                    'xmlns:xsi=&quot;http://www.w3.org/2001/XMLSchema-instance&quot; '
#                    'xmlns:xsd=&quot;http://www.w3.org/2001/XMLSchema&quot; '
#                    'xmlns:soap=&quot;http://schemas.xmlsoap.org/soap/envelope/&quot;&gt;\n'
#                    '    &lt;soap:Header&gt;\n'
#                    '        &lt;AuthenticationHeader '
#                    'xmlns=&quot;http://url/omitted/&quot;&gt;\n'
#                    '            &lt;userName&gt;{{username}}&lt;/userName&gt;\n'
#                    '            '
#                    '&lt;userPassword&gt;{{password}}&lt;/userPassword&gt;\n'
#                    '        &lt;/AuthenticationHeader&gt;\n'
#                    '    &lt;/soap:Header&gt;\n'
#                    '    &lt;soap:Body&gt;\n'
#                    '        &lt;GetDeviceCommands '
#                    'xmlns=&quot;http://url/omitted/&quot;&gt;\n'
#                    '            '
#                    '&lt;datagateId&gt;{{datagateid}}&lt;/datagateId&gt;\n'
#                    '        &lt;/GetDeviceCommands&gt;\n'
#                    '    &lt;/soap:Body&gt;\n'
#                    '&lt;/soap:Envelope&gt;\n'
#                    '</code></pre>\n'
#                    '<p>The Error:</p>\n'
#                    '<pre><code>&lt;soap:Fault&gt;\n'
#                    '    &lt;faultcode&gt;soap:Server&lt;/faultcode&gt;\n'
#                    '    &lt;faultstring&gt;Server was unable to process '
#                    'request. ---&amp;gt; Request for principal permission '
#                    'failed.&lt;/faultstring&gt;\n'
#                    '    &lt;detail /&gt;\n'
#                    '&lt;/soap:Fault&gt;\n'
#                    '</code></pre>\n'
#                    '<p>I get the same error when I make the request from a c# '
#                    'console app. Confirmed has nothing to do with '
#                    'postman.</p>\n'
#                    '<pre><code>System.AggregateException: '
#                    "'constructorArgs[0]Server was unable to process\n"
#                    'request. ---&gt; Request for principal permission '
#                    "failed.)'\n"
#                    '\n'
#                    'Inner Exception\n'
#                    'FaultException: Server was unable to process request. '
#                    '---&gt; Request for principal permission failed.\n'
#                    '</code></pre>\n',
#                    '<p>I am trying to count the number of times [Tracking id] '
#                    '&amp; [Tracking ID1] appear in a table.</p>\n'
#                    '<p><a href="https://i.stack.imgur.com/5359e.png" '
#                    'rel="nofollow noreferrer"><img '
#                    'src="https://i.stack.imgur.com/5359e.png" alt="enter image '
#                    'description here" /></a></p>\n'
#                    '<p>The result should look like this.</p>\n'
#                    '<p><a href="https://i.stack.imgur.com/krIcf.png" '
#                    'rel="nofollow noreferrer"><img '
#                    'src="https://i.stack.imgur.com/krIcf.png" alt="enter image '
#                    'description here" /></a></p>\n'
#                    '<p>This works great when I use a group by function.</p>\n'
#                    '<pre><code>select [Group], datename(month,[date]) as '
#                    'Month, count([Tracking ID]) + count([Tracking ID1]) as '
#                    '[Number of Record]\n'
#                    'from   [Table]\n'
#                    'group by    \n'
#                    '    [Group],\n'
#                    '    datename(month,[date]) \n'
#                    '</code></pre>\n'
#                    '<p>I need to use a pivot function. How do I modify the '
#                    'code below to get the desired results</p>\n'
#                    '<pre><code>select * \n'
#                    'from \n'
#                    '    (\n'
#                    'select  \n'
#                    '    [Group], datename(month,[date]) as Month, '
#                    '(count([Tracking ID])over () + count([Tracking ID1]) over '
#                    '() ) as [Number of Record]\n'
#                    'From    \n'
#                    '    [Table]\n'
#                    ') sourcetbl\n'
#                    'pivot\n'
#                    '    (count([Number of Record])  \n'
#                    'for [Month] in ([June], [July])\n'
#                    ') as pivotTable;\n'
#                    '</code></pre>\n'
#                    '<p>Currently, my query returns 2 instead of 4.</p>\n'
#                    '<p><a href="https://i.stack.imgur.com/YbQcW.png" '
#                    'rel="nofollow noreferrer"><img '
#                    'src="https://i.stack.imgur.com/YbQcW.png" alt="enter image '
#                    'description here" /></a></p>\n',
#                    '<p>I want to get the returned data whenever fetching is '
#                    'done, because the correct timestamp will be there after '
#                    'fully fetching however the function will return the link '
#                    'with an empty timestamp instead of the latest timestamp of '
#                    'all the data.</p>\n'
#                    '<pre><code>async function pushData(url) {\n'
#                    '  let settings = { method: &quot;Get&quot; };\n'
#                    '  let timestamp = &quot;&quot;;\n'
#                    '  let i = 0;\n'
#                    '\n'
#                    '  fetch(url, settings)\n'
#                    '      .then(res =&gt; res.json())\n'
#                    '      .then((json) =&gt; {\n'
#                    '        json.forEach(function (object) {\n'
#                    '          console.log(object);\n'
#                    '          i++;\n'
#                    '        });\n'
#                    '        timestamp = json[i-1].timestamp;\n'
#                    '      });\n'
#                    '\n'
#                    '  return await '
#                    "'https://www.bitmex.com/api/v1/trade?count=1000&amp;symbol=XBTUSD&amp;startTime=' "
#                    '+ timestamp;\n'
#                    '}\n'
#                    '\n'
#                    'var test = '
#                    "pushData('https://www.bitmex.com/api/v1/trade?count=1000&amp;symbol=XBTUSD');\n"
#                    'console.log(test);\n'
#                    '</code></pre>\n',
#                    "<p>I'm trying to add text with small caps in the Word "
#                    'API.  I read through the paragraph documentation and saw '
#                    "it wasn't implemented using the "
#                    '<code>insertParagraph</code> method.  I was hoping to '
#                    'circumvent that by using either <code>insertHtml</code> or '
#                    '<code>insertOoxml</code>.</p>\n'
#                    '<p>Right now, my current attempt is to use insertHtml to '
#                    'try to insert the following paragraph</p>\n'
#                    '<pre class="lang-js '
#                    'prettyprint-override"><code>range.insertHtml(\'text '
#                    '&lt;i&gt;inserted&lt;/i&gt; &lt;p '
#                    'style=&quot;font-variant: small-caps&quot;&gt; With '
#                    '&lt;/p&gt; &lt;b&gt;insert  &lt;p&gt;Html&lt;/b&gt; '
#                    "&lt;/p&gt; Hello!!!  ', Word.InsertLocation.before);\n"
#                    '</code></pre>\n'
#                    '<p>It seems the office api is stripping that out.  I tried '
#                    'changing the font family with the same code and that '
#                    'worked fine.</p>\n'
#                    '<p>Does anyone know a work around to this?</p>\n',
#                    '<p>With persistence enabled in <code>broker.xml</code> and '
#                    'when <code>-Xms</code> &amp; <code>-Xmx</code> are set to '
#                    '4GB and <code>global-max-size</code> set to default 200Mb '
#                    '(most of the setting were just created by the Artemis '
#                    '<code>create</code> command) I am getting the below '
#                    'exceptions either within a day or three based on the rate '
#                    'of data processed. Configuration is similar to <a '
#                    'href="https://stackoverflow.com/questions/63235169/apache-artemis-logs-amq212037-connection-failure-and-connection-reset-by-peer">this '
#                    'post</a>.</p>\n'
#                    '<pre><code>2020-08-03 02:25:58,969 WARN  '
#                    '[org.apache.activemq.artemis.core.server] AMQ222033: Page '
#                    'file 000000005.page had incomplete records at position '
#                    '9,259,622 at record number 4,224\n'
#                    '2020-08-03 02:31:19,390 WARN  '
#                    '[org.apache.activemq.artemis.core.server] AMQ222288: Page '
#                    '5, message 4,224 could not be found on offset 9,259,622, '
#                    'with starting message 4,224. This represents a logic error '
#                    'or inconsistency on the data, and the system will try once '
#                    'again from the beggining of the page file.\n'
#                    '2020-08-03 03:05:10,331 WARN  '
#                    '[org.apache.activemq.artemis.utils.actors.OrderedExecutor] '
#                    'Java heap space: java.lang.OutOfMemoryError: Java heap '
#                    'space\n'
#                    '\n'
#                    '</code></pre>\n'
#                    '<p>I was able to confirm the heap was 100%.</p>\n'
#                    '<pre><code>Heap Usage:\n'
#                    'G1 Heap:\n'
#                    '   regions  = 2048\n'
#                    '   capacity = 4294967296 (4096.0MB)\n'
#                    '   used     = 4285561048 (4087.0295028686523MB)\n'
#                    '   free     = 9406248 (8.970497131347656MB)\n'
#                    '   99.78099372237921% used\n'
#                    'G1 Young Generation:\n'
#                    'Eden Space:\n'
#                    '   regions  = 0\n'
#                    '   capacity = 8388608 (8.0MB)\n'
#                    '   used     = 0 (0.0MB)\n'
#                    '   free     = 8388608 (8.0MB)\n'
#                    '   0.0% used\n'
#                    'Survivor Space:\n'
#                    '   regions  = 0\n'
#                    '   capacity = 0 (0.0MB)\n'
#                    '   used     = 0 (0.0MB)\n'
#                    '   free     = 0 (0.0MB)\n'
#                    '   0.0% used\n'
#                    'G1 Old Generation:\n'
#                    '   regions  = 2048\n'
#                    '   capacity = 4286578688 (4088.0MB)\n'
#                    '   used     = 4285561048 (4087.0295028686523MB)\n'
#                    '   free     = 1017640 (0.9704971313476562MB)\n'
#                    '   99.97625985490832% used\n'
#                    '\n'
#                    '14525 interned Strings occupying 1435888 bytes.\n'
#                    '\n'
#                    '</code></pre>\n'
#                    '<p>Using Artemis version 2.13.0. VM is a 2 core Linux '
#                    'machine with 7 GB RAM. I had disabled the persistence. '
#                    'Also another observation is the RES size is growing '
#                    'gradually when I use the top command.</p>\n'
#                    '<p>Client configuration: (using camel and activeMq JMS '
#                    'component)</p>\n'
#                    '<pre><code>  &lt;bean id=&quot;conxnFactory&quot; '
#                    'class=&quot;org.apache.activemq.ActiveMQConnectionFactory&quot;&gt;\n'
#                    '      &lt;property name=&quot;brokerURL&quot; '
#                    'value=&quot;tcp://domain-name:port&quot; /&gt;\n'
#                    '    &lt;/bean&gt;\n'
#                    '\n'
#                    '    &lt;bean id=&quot;pooledconxnFactory&quot; '
#                    'class=&quot;org.apache.activemq.pool.PooledConnectionFactory&quot; '
#                    'init-method=&quot;start&quot; '
#                    'destroy-method=&quot;stop&quot;&gt;\n'
#                    '      &lt;property name=&quot;maxConnections&quot; '
#                    'value=&quot;5&quot; /&gt;\n'
#                    '      &lt;property name=&quot;connectionFactory&quot; '
#                    'ref=&quot;conxnFactory&quot; /&gt;\n'
#                    '    &lt;/bean&gt;\n'
#                    '\n'
#                    '    &lt;bean id=&quot;config&quot; '
#                    'class=&quot;org.apache.camel.component.jms.JmsConfiguration&quot;&gt;\n'
#                    '      &lt;property name=&quot;connectionFactory&quot; '
#                    'ref=&quot;pooledconxnFactory&quot; /&gt;\n'
#                    '      &lt;property name=&quot;concurrentConsumers&quot; '
#                    'value=&quot;5&quot; /&gt;\n'
#                    '    &lt;/bean&gt;\n'
#                    '\n'
#                    '    &lt;bean id=&quot;jmsqueue&quot; '
#                    'class=&quot;org.apache.activemq.camel.component.ActiveMQComponent&quot;&gt;\n'
#                    '      &lt;property name=&quot;configuration&quot; '
#                    'ref=&quot;config&quot; /&gt;\n'
#                    '    &lt;/bean&gt;\n'
#                    '    \n'
#                    '    &lt;camelContext id=&quot;camel&quot; '
#                    'xmlns=&quot;http://camel.apache.org/schema/spring&quot;&gt;\n'
#                    '      &lt;endpoint id=&quot;inputQueue&quot; '
#                    'uri=&quot;jmsqueue:queue:dataqueue1&quot; /&gt;\n'
#                    '      \n'
#                    '      &lt;route&gt;\n'
#                    '        &lt;from uri=&quot;ref:inputQueue&quot; /&gt;\n'
#                    '...\n'
#                    '</code></pre>\n'
#                    '<p>I was not able to get the heapdump, but there was a '
#                    'hs_err_pid file generated.</p>\n'
#                    '<pre><code>...\n'
#                    'Other Threads:\n'
#                    '  0x00007f9d10282000 VMThread [stack: '
#                    '0x00007f9d147a4000,0x00007f9d148a4000] [id=68249]\n'
#                    '  0x00007f9d102d2800 WatcherThread [stack: '
#                    '0x00007f9d00f00000,0x00007f9d01000000] [id=68257]\n'
#                    '\n'
#                    '=&gt;0x00007f9d10023000 (exited) GCTaskThread [stack: '
#                    '0x00007f9d16eaa000,0x00007f9d16faa000] [id=68242]\n'
#                    '\n'
#                    'VM state:at safepoint (normal execution)\n'
#                    '\n'
#                    'VM Mutex/Monitor currently owned by a thread:  '
#                    '([mutex/lock_event])\n'
#                    '[0x00007f9d10007bd0] Threads_lock - owner thread: '
#                    '0x00007f9d10282000\n'
#                    '[0x00007f9d100080d0] Heap_lock - owner thread: '
#                    '0x00007f9cf421d800\n'
#                    '\n'
#                    'Heap:\n'
#                    ' garbage-first heap   total 2097152K, used 2088898K '
#                    '[0x0000000080000000, 0x0000000080104000, '
#                    '0x0000000100000000)\n'
#                    '  region size 1024K, 0 young (0K), 0 survivors (0K)\n'
#                    ' Metaspace       used 46102K, capacity 46842K, committed '
#                    '47408K, reserved 1091584K\n'
#                    '  class space    used 5086K, capacity 5295K, committed '
#                    '5424K, reserved 1048576K\n'
#                    '\n'
#                    'Heap Regions: (Y=young(eden), SU=young(survivor), '
#                    'HS=humongous(starts), HC=humongous(continues), '
#                    'CS=collection set, F=free, TS=gc time stamp, '
#                    'PTAMS=previous top-at-mark-start, NTAMS=next '
#                    'top-at-mark-start)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080000000 NTAMS '
#                    '0x0000000080000000 space 1024K,  99% used '
#                    '[0x0000000080000000, 0x0000000080100000)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080100000 NTAMS '
#                    '0x0000000080100000 space 1024K,  99% used '
#                    '[0x0000000080100000, 0x0000000080200000)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080200000 NTAMS '
#                    '0x0000000080200000 space 1024K,  99% used '
#                    '[0x0000000080200000, 0x0000000080300000)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080300000 NTAMS '
#                    '0x0000000080300000 space 1024K,  99% used '
#                    '[0x0000000080300000, 0x0000000080400000)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080400000 NTAMS '
#                    '0x0000000080400000 space 1024K,  99% used '
#                    '[0x0000000080400000, 0x0000000080500000)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080500000 NTAMS '
#                    '0x0000000080500000 space 1024K,  99% used '
#                    '[0x0000000080500000, 0x0000000080600000)\n'
#                    'AC   0  O    TS     0 PTAMS 0x0000000080600000 NTAMS '
#                    '0x0000000080600000 space 1024K,  98% used '
#                    '[0x0000000080600000, 0x0000000080700000)\n'
#                    '....\n'
#                    '...\n'
#                    'Deoptimization events (10 events):\n'
#                    'Event: 26931.254 Thread 0x00007f9ce0031000 Uncommon trap: '
#                    'reason=bimorphic action=maybe_recompile '
#                    'pc=0x00007f9d01589b58 '
#                    'method=java.util.AbstractCollection.toArray()[Ljava/lang/Object; '
#                    '@ 1\n'
#                    'Event: 26940.746 Thread 0x00007f9cbc4e7800 Uncommon trap: '
#                    'reason=class_check action=maybe_recompile '
#                    'pc=0x00007f9d01c69704 '
#                    'method=org.apache.activemq.artemis.core.remoting.impl.netty.ActiveMQChannelHandler.lambda$channelInactive$0(Lio/netty/channel/ChannelHandlerContext;)V '
#                    '@ 13\n'
#                    'Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: '
#                    'reason=unstable_if action=reinterpret '
#                    'pc=0x00007f9d01f98b44 '
#                    'method=org.apache.activemq.artemis.utils.UUID.toString()Ljava/lang/String; '
#                    '@ 4\n'
#                    'Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: '
#                    'reason=class_check action=maybe_recompile '
#                    'pc=0x00007f9d02a77920 '
#                    'method=org.apache.activemq.artemis.core.server.impl.QueueImpl$ConsumerHolder.getPriority()I '
#                    '@ 4\n'
#                    'Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: '
#                    'reason=class_check action=maybe_recompile '
#                    'pc=0x00007f9d011dcd40 '
#                    'method=org.apache.activemq.artemis.core.server.impl.QueueImpl$ConsumerHolder.getPriority()I '
#                    '@ 4\n'
#                    'Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: '
#                    'reason=unstable_if action=reinterpret '
#                    'pc=0x00007f9d01ba2a84 '
#                    'method=java.lang.AbstractStringBuilder.append(I)Ljava/lang/AbstractStringBuilder; '
#                    '@ 16\n'
#                    'Event: 27142.215 Thread 0x0000000001333000 Uncommon trap: '
#                    'reason=unstable_if action=reinterpret '
#                    'pc=0x00007f9d02660584 '
#                    'method=java.net.InetAddress.toString()Ljava/lang/String; @ '
#                    '16\n'
#                    'Event: 27142.216 Thread 0x0000000001333000 Uncommon trap: '
#                    'reason=class_check action=maybe_recompile '
#                    'pc=0x00007f9d029b9650 '
#                    'method=org.apache.activemq.artemis.utils.ActiveMQThreadPoolExecutor$ThreadPoolQueue.offer(Ljava/lang/Object;)Z '
#                    '@ 2\n'
#                    'Event: 29769.075 Thread 0x00007f9d10b14000 Uncommon trap: '
#                    'reason=unstable_if action=reinterpret '
#                    'pc=0x00007f9d0267c37c '
#                    'method=java.util.concurrent.FutureTask.runAndReset()Z @ '
#                    '115\n'
#                    'Event: 30265.745 Thread 0x00007f9d106f3800 Uncommon trap: '
#                    'reason=unstable_if action=reinterpret '
#                    'pc=0x00007f9d0267c418 '
#                    'method=java.util.concurrent.FutureTask.run()V @ 66\n'
#                    '\n'
#                    'Internal exceptions (10 events):\n'
#                    'Event: 31469.887 Thread 0x00007f9cf4007800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31486.605 Thread 0x00007f9cf4007800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31504.901 Thread 0x00007f9cf4007800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31522.574 Thread 0x00007f9cf4007800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31538.769 Thread 0x00007f9d110a4000 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31556.358 Thread 0x00007f9d110a4000 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31574.508 Thread 0x00007f9d110a4000 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31590.147 Thread 0x00007f9d10e37800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31606.743 Thread 0x00007f9d10e37800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, '
#                    'line 159]\n'
#                    'Event: 31606.743 Thread 0x00007f9d10e37800 Exception &lt;a '
#                    "'java/lang/OutOfMemoryError'&gt; (0x000000008004f068) "
#                    'thrown at '
#                    '[/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/runtime/deoptimization.cpp, '
#                    'line 790]\n'
#                    '\n'
#                    'Events (10 events):\n'
#                    'Event: 31590.147 Executing VM operation: '
#                    'G1CollectForAllocation done\n'
#                    'Event: 31590.148 Executing VM operation: '
#                    'G1IncCollectionPause\n'
#                    'Event: 31590.167 Executing VM operation: '
#                    'G1IncCollectionPause done\n'
#                    'Event: 31590.167 Executing VM operation: '
#                    'G1IncCollectionPause\n'
#                    'Event: 31590.175 Executing VM operation: '
#                    'G1IncCollectionPause done\n'
#                    'Event: 31590.188 Executing VM operation: '
#                    'G1CollectForAllocation\n'
#                    'Event: 31606.743 Executing VM operation: '
#                    'G1CollectForAllocation done\n'
#                    'Event: 31606.743 Thread 0x00007f9d10e37800 DEOPT PACKING '
#                    'pc=0x00007f9d021831a8 sp=0x00007f9ce46b4f00\n'
#                    'Event: 31606.743 Thread 0x00007f9d10e37800 DEOPT UNPACKING '
#                    'pc=0x00007f9d01047373 sp=0x00007f9ce46b4be0 mode 1\n'
#                    'Event: 31606.749 Executing VM operation: '
#                    'G1IncCollectionPause\n'
#                    '..\n'
#                    '</code></pre>\n'
#                    'Update:\n'
#                    '<p>Not able to get the heap dump, as the broker instance '
#                    'hangs after logging the below message in logs</p>\n'
#                    '<pre><code>2020-08-07 00:17:32,835 WARNING '
#                    '[sun.rmi.transport.tcp] RMI TCP Accept-0: accept loop for '
#                    'ServerSocket[addr=localhost/127.0.0.1,localport=33088] '
#                    'throws: java.lang.OutOfMemoryError: Java heap space\n'
#                    '\n'
#                    '2020-08-07 00:17:49,675 WARN  '
#                    '[org.apache.activemq.artemis.utils.actors.OrderedExecutor] '
#                    'Java heap space: java.lang.OutOfMemoryError: Java heap '
#                    'space\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.impl.Page.readMessage(Page.java:208) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageReader.getMessage(PageReader.java:94) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl.internalGetNext(PageSubscriptionImpl.java:432) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl.access$2200(PageSubscriptionImpl.java:67) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.moveNext(PageSubscriptionImpl.java:1353) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.next(PageSubscriptionImpl.java:1318) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.tryNext(PageSubscriptionImpl.java:1445) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.hasNext(PageSubscriptionImpl.java:1461) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.QueueImpl.checkDepage(QueueImpl.java:2989) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.QueueImpl.deliverAsync(QueueImpl.java:1243) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.QueueImpl.deliverAsync(QueueImpl.java:1237) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.ServerConsumerImpl.forceDelivery(ServerConsumerImpl.java:1154) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.ServerConsumerImpl.promptDelivery(ServerConsumerImpl.java:1146) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.ServerConsumerImpl.setStarted(ServerConsumerImpl.java:755) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.ServerSessionImpl.setStarted(ServerSessionImpl.java:2013) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.server.impl.ServerSessionImpl.start(ServerSessionImpl.java:1667) '
#                    '[artemis-server-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.protocol.openwire.amq.AMQSession.start(AMQSession.java:269) '
#                    '[artemis-openwire-protocol-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection.addConsumer(OpenWireConnection.java:908) '
#                    '[artemis-openwire-protocol-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection$CommandProcessor.processAddConsumer(OpenWireConnection.java:1194) '
#                    '[artemis-openwire-protocol-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.command.ConsumerInfo.visit(ConsumerInfo.java:351) '
#                    '[activemq-client-5.14.5.jar:5.14.5]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection.act(OpenWireConnection.java:322) '
#                    '[artemis-openwire-protocol-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection$$Lambda$124/267018299.onMessage(Unknown '
#                    'Source)\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.Actor.doTask(Actor.java:33) '
#                    '[artemis-commons-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.ProcessorBase.executePendingTasks(ProcessorBase.java:65) '
#                    '[artemis-commons-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.ProcessorBase$$Lambda$35/656479172.run(Unknown '
#                    'Source)\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.OrderedExecutor.doTask(OrderedExecutor.java:42) '
#                    '[artemis-commons-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.OrderedExecutor.doTask(OrderedExecutor.java:31) '
#                    '[artemis-commons-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.ProcessorBase.executePendingTasks(ProcessorBase.java:65) '
#                    '[artemis-commons-2.13.0.jar:2.13.0]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.actors.ProcessorBase$$Lambda$35/656479172.run(Unknown '
#                    'Source)\n'
#                    '        at '
#                    'java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142) '
#                    '[rt.jar:1.8.0_131]\n'
#                    '        at '
#                    'java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617) '
#                    '[rt.jar:1.8.0_131]\n'
#                    '        at '
#                    'org.apache.activemq.artemis.utils.ActiveMQThreadFactory$1.run(ActiveMQThreadFactory.java:118) '
#                    '[artemis-commons-2.13.0.jar:2.13.0]\n'
#                    '</code></pre>\n'
#                    '<p>With the persistence flag as false in broker.xml, the '
#                    'heap issue occurred only once. (as mentioned the logs '
#                    'above)</p>\n'
#                    '<p>Enabling <code>artemis.profile</code> to log '
#                    "oom_heapdump.hprof didn't log any info but exception with "
#                    'Thread dump info.</p>\n'
#                    '<p>The below message is also noticed frequently in the '
#                    'logs.</p>\n'
#                    '<pre><code>2020-08-09 17:51:03,484 WARN  '
#                    '[org.apache.activemq.artemis.core.server] AMQ222038: '
#                    "Starting paging on address 'ActiveMQ.Advisory.TempQueue'; "
#                    'size is currently: 2,147,471,789 bytes; max-size-bytes: '
#                    '-1; global-size-bytes: 2,147,486,900\n'
#                    '</code></pre>\n'
#                    '<p>The clients (consumer) uses OPENWIRE using '
#                    'activemq-5.13 client jar. From the broker console, the '
#                    'producer use CORE protocol.</p>\n'
#                    '<p>Jvisual VM for Broker running straight 20 hrs</p>\n'
#                    '<p><a href="https://i.stack.imgur.com/euwWm.png" '
#                    'rel="nofollow noreferrer"><img '
#                    'src="https://i.stack.imgur.com/euwWm.png" alt="visualVM '
#                    'monitor" /></a></p>\n'
#                    '<p>I enabled the JAVA_ARGS to print the OOM trace a 7 GB '
#                    'file got generated, below is the analysis using Eclipse '
#                    'MAT tool.</p>\n'
#                    '<p><a href="https://i.stack.imgur.com/TkKcJ.png" '
#                    'rel="nofollow noreferrer"><img '
#                    'src="https://i.stack.imgur.com/TkKcJ.png" alt="histogram '
#                    'of heap" /></a></p>\n'
#                    '<p>1.2G shallow heap consumption by '
#                    '<code>org.apache.activemq.artemis.core.paging.cursor.impl.PagePosistionImpl</code>.</p>\n'
#                    '<p>From the Docs, when address-full-policy is set to PAGE '
#                    'that is the time broker starts appending to page. Other '
#                    'values are DROP and BLOCK (blocks producer, until memory '
#                    'is freed). I planning to use address-full-policy to BLOCK '
#                    'to see if the OOM issue exists.</p>\n',
#                    '<p>Whenever I tried to add <code>photos</code> permission '
#                    'on my scope it always giving this message while '
#                    'login:</p>\n'
#                    '<p><a href="https://i.stack.imgur.com/BGcIo.png" '
#                    'rel="nofollow noreferrer"><img '
#                    'src="https://i.stack.imgur.com/BGcIo.png" alt="enter image '
#                    'description here" /></a></p>\n'
#                    '<p>Without <code>photos</code> permission it is working '
#                    'perfectly. Here is my code:</p>\n'
#                    "<pre><code>document.getElementById('fb-login-btn').addEventListener('click', "
#                    'function() {\n'
#                    '   FB.login((response) =&gt; {\n'
#                    '     statusChangeCallback(response);\n'
#                    "   }, {scope: 'public_profile,photos', return_scopes: "
#                    "true}); //{scope: 'public_profile,email', return_scopes: "
#                    'true});\n'
#                    ' }, false);   \n'
#                    '</code></pre>\n'
#                    "<p>I don't think the problem lies in code, because the "
#                    'same problem also occurred with default <code>facebook '
#                    'login button</code> as well, when I added '
#                    '<code>photos</code> permission. Any suggestions?</p>\n',
#                    '<p>we have the following setup, which seems to override '
#                    'each other:</p>\n'
#                    '<ul>\n'
#                    '<li>following the tinyMCE angular <a '
#                    'href="https://www.tiny.cloud/docs/integrations/angular/#usingwithreactiveforms" '
#                    'rel="nofollow noreferrer">integration docs</a></li>\n'
#                    '<li>angular reactive forms (angular 9), which are '
#                    'generated dynamicaly based on a type, eg. '
#                    '<strong>html</strong>:</li>\n'
#                    '</ul>\n'
#                    '<pre class="lang-js prettyprint-override"><code>private '
#                    'generateFormConfig() {\n'
#                    '    const formConfig = {};\n'
#                    '\n'
#                    '    // ...\n'
#                    '\n'
#                    '    formConfig[controlId] = new FormControl(\n'
#                    '        value,\n'
#                    '        Validators.compose(formValidators)\n'
#                    '    );\n'
#                    '\n'
#                    '    // ...\n'
#                    '    this.form = this.formBuilder.group(formConfig);\n'
#                    '}\n'
#                    '</code></pre>\n'
#                    '<ul>\n'
#                    '<li>the form is then rendered inside a ionic modal '
#                    'component also with a dynamic *ngFor:</li>\n'
#                    '</ul>\n'
#                    '<pre class="lang-html '
#                    'prettyprint-override"><code>&lt;ng-template #formItems '
#                    'let-definition=&quot;definition&quot; '
#                    'let-data=&quot;data&quot; let-path=&quot;path&quot; '
#                    'let-errors=&quot;errors&quot;&gt;\n'
#                    '  &lt;div [formGroup]=&quot;form&quot;&gt;\n'
#                    '    &lt;div *ngFor=&quot;let formItemConf of '
#                    'definition&quot;&gt;\n'
#                    '      &lt;div [ngSwitch]=&quot;formItemConf.input&quot; '
#                    "[class]=&quot;'input-wrp input-wrp--' + "
#                    'formItemConf.input&quot;&gt;\n'
#                    '\n'
#                    '        &lt;ion-input *ngSwitchDefault '
#                    '[type]=&quot;formItemConf.type&quot; '
#                    '[formControlName]=&quot;getFormItemId(path, '
#                    'formItemConf.id)&quot; '
#                    'class=&quot;form-control&quot;&gt;&lt;/ion-input&gt;\n'
#                    '\n'
#                    "        &lt;editor *ngSwitchCase=&quot;'html'&quot; "
#                    '[id]=&quot;formItemConf.id&quot; [init]=&quot;{\n'
#                    '              height: 300,\n'
#                    '              resize: true,\n'
#                    '              convert_urls: false,\n'
#                    "              menubar: 'edit view format',\n"
#                    "              plugins: 'paste link lists code',\n"
#                    "              toolbar: 'undo redo |  formatselect bold "
#                    'italic underline | bullist numlist | link | alignleft '
# ...
#                    'newer chrome version</p>\n'
#                    '<p>Thanks</p>\n',
#                    '<p>I guess the code below is more clear than any '
#                    'explaination</p>\n'
#                    '<p><a '
#                    'href="https://dartpad.dartlang.org/a5107762d7f5d564f0f20206ddbd48d1" '
#                    'rel="nofollow '
#                    'noreferrer">https://dartpad.dartlang.org/a5107762d7f5d564f0f20206ddbd48d1</a></p>\n'
#                    '<p>as for the title: is there a way to avoid calling '
#                    '&quot;super&quot; every time I extend a class?</p>\n'
#                    '<p>thank you</p>\n',
#                    '<p>I am trying to get how many members a certain member '
#                    'has invited. The code below works, but it counts all '
#                    'invited members including members that have left.\n'
#                    'I want it to show only the amount of invited members which '
#                    'are still on the server.</p>\n'
#                    '<pre><code>var user = null;\n'
#                    'user = message.mentions.members.first() || '
#                    'message.author;\n'
#                    '        \n'
#                    'message.guild.fetchInvites()\n'
#                    '.then(invites =&gt;\n'
#                    '{\n'
#                    '    const userInvites = invites.array().filter(o =&gt; '
#                    'o.inviter.id === user.id);\n'
#                    '    var userInviteCount = 0;\n'
#                    '\n'
#                    '    for(var i=0; i &lt; userInvites.length; i++)\n'
#                    '    {\n'
#                    '        var invite = userInvites[i];\n'
#                    "        userInviteCount += invite['uses'];\n"
#                    "        userInviteCount - invite['left'];\n"
#                    '    }\n'
#                    '\n'
#                    '    message.reply(`You have ${userInviteCount} '
#                    'invites.`);\n'
#                    '});\n'
#                    '</code></pre>\n',
#                    '<p>I am learning WEKA, I want to increase the heap '
#                    'size.</p>\n'
#                    '<p>I did Q&amp;A researches, most of the answers showed '
#                    'that heap size can be changed in '
#                    "<strong>RunWeka.ini</strong>, but I couldn't find "
#                    '<strong>RunWeka.ini</strong> and also maxheap.</p>\n'
#                    '<p><strong>My WEKA version is Weka 3.8.4</strong>\n'
#                    '<img src="https://i.stack.imgur.com/kxTWW.png" alt="enter '
#                    'image description here" /></p>\n',
#                    '<p>i am trying to add default arguments to a glue job on '
#                    'AWS CDK, specifically the bookmark option enabled. keep on '
#                    'getting the same error:</p>\n'
#                    '<p><code>Error: Resolution error: Supplied properties not '
#                    'correct for &quot;CfnJobProps&quot; defaultArguments: '
#                    '&quot;--job-bookmark-option: job-bookmark-enable&quot; '
#                    "should be an 'object'. </code></p>\n"
#                    '<p>my bode is below:</p>\n'
#                    '<pre><code>    glueETLJob = _glue.CfnJob(\n'
#                    '        self,\n'
#                    '        glueJobName,\n'
#                    '        command =_glue.CfnJob.JobCommandProperty(\n'
#                    '            name = glueJobName,\n'
#                    "            python_version= '3',\n"
#                    '            script_location = config_bucket_arn + '
#                    '&quot;/code/gluejob.py&quot;\n'
#                    '        ),\n'
#                    '        role=glueJobRole.role_arn,\n'
#                    "        glue_version='1.0',\n"
#                    '        max_retries=0,\n'
#                    '        timeout=30,\n'
#                    '        '
#                    'security_configuration=glueSecurityConfiguration.ref,\n'
#                    '        default_arguments=str(&quot;--job-bookmark-option: '
#                    'job-bookmark-enable&quot;),\n'
#                    '        description=&quot;glue job&quot;\n'
#                    '    )\n'
#                    '</code></pre>\n',
#                    '<p>I am using Django 3.0.8.</p>\n'
#                    '<p><strong>settings.py</strong></p>\n'
#                    '<pre><code>INSTALLED_APPS = [\n'
#                    "    'admin_aux.apps.AdminAuxConfig', # PROJECT_APPS\n"
#                    '</code></pre>\n'
#                    '<p><strong>apps.py</strong></p>\n'
#                    '<pre><code>from django.apps import AppConfig\n'
#                    '\n'
#                    '\n'
#                    'class AdminAuxConfig(AppConfig):\n'
#                    "    name = 'admin_aux'\n"
#                    '\n'
#                    '    def ready(self):\n'
#                    '        import admin_aux.allauth_avatar # Breakpoint. '
#                    'Stopps here when the server is run.\n'
#                    '</code></pre>\n'
#                    '<p><strong>admin_aux/allauth_avatar.py</strong></p>\n'
#                    "<pre><code>@receiver(user_signed_up) # Breakpoint. Doesn't "
#                    'stop here when the server is run.\n'
#                    'def on_user_signed_up(sender, request, *args, **kwargs):\n'
#                    "    sociallogin = kwargs.get('sociallogin')\n"
#                    '    if sociallogin:\n'
#                    '        copy_avatar(request,\n'
#                    '                    sociallogin.account.user,\n'
#                    '                    sociallogin.account)\n'
#                    '</code></pre>\n'
#                    "<p>Problem: the receiver doesn't receive the signal.</p>\n"
#                    '<p>I marked breakpoints in the code.</p>\n'
#                    '<p>When I run debugging in PyCharm, I expect that the '
#                    'interpreter will stop at the breakpoint in '
#                    "allauth_avatar.py. But it doesn't. So, signal seems to be "
#                    'not connected. How can I resolve this?</p>\n',
#                    '<p>I have a group of print servers that I want to monitor '
#                    'from a database server, by collecting event log data into '
#                    'a table in my SQL Server database.</p>\n'
#                    '<p>I am writing a Powershell script to be scheduled on my '
#                    'database server, to get all printer servers data. I would '
#                    'prefer to avoid creation of temp files in '
#                    '<code>printservers</code> (and if possible in database '
#                    'server) to avoid cleaning up.</p>\n'
#                    '<p>I am running Powershell as admin and using the '
#                    'following code:</p>\n'
#                    '<pre><code>    $PrintServerName = '
#                    '&quot;usqasws0502.phx-dc.com&quot;\n'
#                    '    $sqlServer = &quot;CZCHOWSTC000583&quot;\n'
#                    '    $Database  = &quot;PrintMonitor&quot;\n'
#                    '    $USusername= &quot;User1&quot;\n'
#                    '    $USpassword= &quot;Passw1&quot;\n'
#                    '\n'
#                    "    $time = @{label='Time Printed'; Expression={get-date "
#                    '$_.TimeCreated -format s}}\n'
#                    "    $documentID = @{label='Document ID'; "
#                    'Expression={$_.properties[0].value}} ## Sample value are '
#                    '181,182,...\n'
#                    "    $documentName = @{label='Document Name'; "
#                    'Expression={$_.properties[1].value}} ## Print Document '
#                    'Constante\n'
#                    "    $userID = @{label='User ID'; "
#                    'Expression={$_.properties[2].value}}  '
#                    '#srv_phxdc-cw1webprin\n'
#                    "    $computerID = @{label='Computer ID'; "
#                    'Expression={$_.properties[3].value}}  ##\\\\USQASWS0500\n'
#                    "    $printer = @{label='Printer'; "
#                    'Expression={$_.properties[4].value}}  '
#                    '##CR-SJO-TSM-XER-LASER-CARGOWISE-AFR1-TSMOFFICE-XEROX\n'
#                    "    $sizeInBytes = @{label='Size in Bytes'; "
#                    'Expression={$_.properties[6].value}}  ## 270181\n'
#                    "    $numberOfPages = @{label='Number of Pages'; "
#                    'Expression={$_.properties[7].value}} ##2\n'
#                    '\n'
#                    '    $TmpFile = '
#                    '&quot;H:\\CWData\\Monitoring\\Printers\\tempfile.csv&quot;\n'
#                    '    $filter = @{ LogName '
#                    '=&quot;Microsoft-Windows-PrintService/Operational&quot;\n'
#                    '                 ID = 307\n'
#                    '                 StartTime = '
#                    '[DateTime]::Today.AddDays(-10)\n'
#                    '                 EndTime =   [DateTime]::Today\n'
#                    '               }\n'
#                    '     $Cred = New-Object PSCredential -ArgumentList '
#                    '@($USusername, ($USpassword|ConvertTo-SecureString '
#                    '-AsPlainText -Force))\n'
#                    '     $s = New-PSSession -ComputerName $PrintServerName '
#                    '-Credential $Cred\n'
#                    '     Invoke-Command -Session $s {\n'
#                    '     $event = Get-WinEvent -FilterHashtable '
#                    '@{LogName=&quot;Microsoft-Windows-PrintService/Operational&quot;; '
#                    'ID=307; StartTime = [DateTime]::Today.AddDays(-10); '
#                    'EndTime = [DateTime]::Today } -ErrorAction '
#                    'SilentlyContinue \n'
#                    '        |Sort TimeCreated -Descending |Format-Table -Wrap '
#                    '-AutoSize \n'
#                    '</code></pre>\n'
#                    '<p>#Line above displays an output like this</p>\n'
#                    '<blockquote>\n'
#                    '<p>TimeCreated            Id LevelDisplayName Message</p>\n'
#                    '</blockquote>\n'
#                    '<hr />\n'
#                    '<blockquote>\n'
#                    '<p>7/27/2020 5:40:32 PM  307 Information      Document '
#                    '253, Print Document owned by SRV_PHXDC-CW1WEBPRIN on\n'
#                    '\\USQASWS0502 was printed on US-LAX-LASER-USLAXNP2LASER13\n'
#                    'through port 7.233.205.205.  Size in bytes: 113367. Pages\n'
#                    'printed: 1. No user action is required.<br />\n'
#                    '7/27/2020 5:40:24 PM  307 Information      Document 252, '
#                    'Print Document owned by SRV_PHXDC-CW1WEBPRIN on\n'
#                    '\\USQASWS0502 was printed on US-LAX-LASER-USLAXNP2LASER13\n'
#                    'through port 7.233.205.205.  Size in bytes: 120234. Pages\n'
#                    'printed: 2. No user action is required.</p>\n'
#                    '</blockquote>\n'
#                    '<pre><code>    $obj= $event |select $time, $documentID, '
#                    '$documentName,$userID, $computerID, $printer, '
#                    '$printerPort, $sizeInBytes, $numberOfPages | export-csv '
#                    '&quot;H:\\CWData\\Monitoring\\Printers\\PrintLog_$ServerName_tempfile.csv&quot;\n'
#                    '    #The line above  generates an empty file..\n'
#                    '    Write-SQLTableData -TableName PrintService-Job '
#                    '-SchemaName dbo -DatabaseName $Database -ServerInstance '
#                    '$sqlServer -InputData  $obj\n'
#                    '    #The line above does not enter anything in the DB '
#                    'generates an empty file..\n'
#                    '</code></pre>\n'
#                    '<p>My database table would be:</p>\n'
#                    '<pre><code>CREATE TABLE [dbo].[PrintService-Job]\n'
#                    '(\n'
#                    '      [pj_id] [int] IDENTITY(1,1) NOT NULL,\n'
#                    '      [pj_DateTime] [varchar](50) NULL,\n'
#                    '      [pj_PrintServer] [varchar](50) NULL,\n'
#                    '      [pj_PrintClient] [varchar](50) NULL,\n'
#                    '      [pj_PrinterName] [varchar](50) NULL,\n'
#                    '      [pj_SizeBytes] [varchar](50) NULL\n'
#                    ')\n'
#                    '</code></pre>\n'
#                    '<p>Can you guide me what I am doing wrong? (or point me to '
#                    'a script that transfer data from Windows event logs to SQL '
#                    'Server database tables)</p>\n'],
#  'post_id': [63239300,
#              63224104,
#              63224935,
#              63234496,
#              63237383,
#              63235230,
#              63233712,
#              63235455,
#              63237587,
#              63244392,
#              63249690,
#              63239647,
#              63234238,
#              63226191,
#              63254016,
#              63218398,
#              63247616,
#              63254234,
#              63205581,
#              63224351,
#              63250005,
#              63214920,
#              63250880,
#              63251481,
#              63253017,
#              63222719],
#  'profile_image_url': ['https://www.gravatar.com/avatar/b0267f35bc49691febef17386d54728c?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/ded581240d45e256d68e6807130c2582?s=128&d=identicon&r=PG&f=1',
#                        'https://i.stack.imgur.com/6wFcg.jpg?s=128&g=1',
#                        'https://www.gravatar.com/avatar/dc4c77dd26dded88dd3d196be106cd94?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/4057228c332e51257f3041ab597c7c73?s=128&d=identicon&r=PG',
#                        'https://lh5.googleusercontent.com/-ebmDzzMuzRQ/AAAAAAAAAAI/AAAAAAAABNM/OuhnEXZ97-k/photo.jpg?sz=128',
#                        'https://www.gravatar.com/avatar/3aae252b0cef6df16e7b8c2020b050da?s=128&d=identicon&r=PG',
#                        'https://i.stack.imgur.com/8htyd.jpg?s=128&g=1',
#                        'https://i.stack.imgur.com/2MOY0.png?s=128&g=1',
#                        'https://www.gravatar.com/avatar/c38f6255df694b842b5f0b588946beee?s=128&d=identicon&r=PG',
#                        'https://lh4.googleusercontent.com/-9YrXTDQImsU/AAAAAAAAAAI/AAAAAAAAELQ/WJsZP3aPFDM/photo.jpg?sz=128',
#                        'https://lh4.googleusercontent.com/-BiwcTfc3e-w/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmdeMfy8TRUKoMkp0ka-Oa2Zotk3A/photo.jpg?sz=128',
#                        'https://www.gravatar.com/avatar/3bc500cf9588bddbdd4fa52fe08ad7cc?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/88f01fcad07a39cf41af8ac708b2c98d?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/546533d812c53dc1f380e8a0c7f62da6?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/b94724b49fe1a75a1f6419e6386cb07e?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/a70a743a77b6a013c20503764c75ae9c?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/eb5d828cfc565a7a8645a987031169fc?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/d93bcd74931c7cd8fc7e7246e9dab318?s=128&d=identicon&r=PG&f=1',
#                        'https://lh6.googleusercontent.com/-LdtSZorvquw/AAAAAAAAAAI/AAAAAAAAAwg/NFbU2DLYCCs/photo.jpg?sz=128',
#                        'https://i.stack.imgur.com/p2ehG.jpg?s=128&g=1',
#                        'https://lh3.googleusercontent.com/a-/AOh14Gh1ZJ2Zo-I04GdhCw3lWMHMR1oNWr2U8YpOGcCyiA=k-s128',
#                        'https://lh3.googleusercontent.com/a-/AOh14GigO0OU1Sfce93c2gyLmtvF4PZkQ8rC09fy-BIYJnA=k-s128',
#                        'https://www.gravatar.com/avatar/bed8d007d46188649af0f2661c9360a6?s=128&d=identicon&r=PG&f=1',
#                        'https://www.gravatar.com/avatar/adabf7f065858c050e95bb5f712b3092?s=128&d=identicon&r=PG',
#                        'https://lh3.googleusercontent.com/a-/AOh14Ggggjq8vCSSAnYgxo1UROzCIujKpwXQWA6L4adsTGo=k-s128']}

# %%
for dn, piu, pi, pc in zip(questions["display_name"], questions["profile_image_url"], questions["post_id"], questions["post_contents"]):
    print("Display Name:", dn)
    print("Profile Image URL:", piu)
    print("Post ID:", pi)
    print("Post Body:", pc)
    print()
# Out:
# Display Name: Dashing
# Profile Image URL: https://www.gravatar.com/avatar/b0267f35bc49691febef17386d54728c?s=128&d=identicon&r=PG&f=1
# Post ID: 63239300
# Post Body: <p>Swift code</p>
# <pre><code>print(&quot;1&quot;, NSObject() == NSObject())
# print(&quot;2&quot;, ObjectIdentifier(NSObject()) == ObjectIdentifier(NSObject()))
# let object3 = NSObject()
# let object4 = NSObject()
# print(&quot;3&quot;, object3, object4)
# print(&quot;4&quot;, ObjectIdentifier(object3) == ObjectIdentifier(object4))
# </code></pre>
# <p>Console result</p>
# <pre><code>1 false
# 2 true
# 3 &lt;NSObject: 0x600000d805f0&gt; &lt;NSObject: 0x600000d80610&gt;
# 4 false
# </code></pre>
# <p>ObjectIdentifier compares instances using their object identifiers and the identical-to operator <code>===</code>. Why NSObject() in print(&quot;1&quot;, ...) is two object, but in print(&quot;2&quot;, ...) is same object?</p>
#
#
# Display Name: Liamdale
# Profile Image URL: https://www.gravatar.com/avatar/ded581240d45e256d68e6807130c2582?s=128&d=identicon&r=PG&f=1
# Post ID: 63224104
# Post Body: <p>I am working on an app using python3 and SqlAlchemy for SQLite3 database management.  I have some tables that have a Many to Many relationship.  I've created an association table to handle this relationship.</p>
# <pre><code>Class Machine(Base):
#     __tablename__ 'machine'
#     machine_ID = Column(Integer, primary_key=True)
#     etc...
# Class Options(Base):
#     __tableName__ 'options'
#     options_ID = Column(Integer, primary_key=True)
#     etc...
#
# The association table
#
# Machine_Options = table('machine_options', Base.metadata,
#     Column('machine_FK', Integer, ForeignKey('machine.machine_ID'),
#                                  primary_key=True),
#     Column('options_FK',Integer, ForeignKey('options.options_ID'),
#                                  primary_key=True))
# </code></pre>
# <p>All the items for the Machine and Options are inserted independently.  When I want to associate a machine with an option I use an append query which works very well.</p>
# <p>My problem is when I want to break this association between a machine and an option.  I have tried a direct row deletion from the association table using a FILTER() clause on the machine_FK and the options_FK but SqlAlchemy gives me an error informing me that 'Machine_Options' table has no field 'machine_FK'.
# I have tried to remove the row from 'Machine_Options' indirectly using joins with the machine and options table but received another error that I can not delete or update using joins.</p>
# <p>I am looking for the code to only delete a row from the association table without affecting the original machine or options table.</p>
# <p>So far my internet search has been fruitless.</p>
#
#
# Display Name: Tinu
# Profile Image URL: https://i.stack.imgur.com/6wFcg.jpg?s=128&g=1
# Post ID: 63224935
# Post Body: <p>When using random forests in <code>R</code> I came across the following situation:</p>
# <pre><code>library(randomForest)
# set.seed(42)
# data(iris)
# rf_noImportance &lt;- randomForest(Species~.,data=iris,ntree=100,importance=F)
# print(table(predict(rf_noImportance),iris$Species))
# </code></pre>
# <p>Output:</p>
# <blockquote>
# <pre><code>            setosa versicolor virginica
#  setosa         50          0         0
#  versicolor      0         47         3
#  virginica       0          3        47
# </code></pre>
# </blockquote>
# <p>and</p>
# <pre><code>library(randomForest)
# set.seed(42)
# data(iris)
# rf_importance &lt;- randomForest(Species~.,data=iris,ntree=100,importance=T)
# print(table(predict(rf_importance),iris$Species))
# </code></pre>
# <p>Output:</p>
# <blockquote>
# <pre><code>            setosa versicolor virginica
#  setosa         50          0         0
#  versicolor      0         47         4
#  virginica       0          3        46
# </code></pre>
# </blockquote>
# <p>In the first example I set <code>importance = FALSE</code> and in the second example <code>TRUE</code>. From my understanding this should not affect the resulting prediction. There's also no indication for that behavior in the <a href="https://cran.r-project.org/web/packages/randomForest/randomForest.pdf" rel="nofollow noreferrer">documentation</a>.</p>
# <p>According to <a href="https://stats.stackexchange.com/q/219498/264183">this</a> cross-validated post the importance flag should not influence the predictions, but it clearly does in the example above.</p>
# <p>So why is the importance parameter of the <code>randomForest</code> method influencing the performance of the model?</p>
#
#
# Display Name: Uuuuuumm
# Profile Image URL: https://www.gravatar.com/avatar/dc4c77dd26dded88dd3d196be106cd94?s=128&d=identicon&r=PG&f=1
# Post ID: 63234496
# Post Body: <p>I am consuming another company's SOAP API via postman and it keeps returning an error</p>
# <p>Based on my research, when people have been getting this error, they are also developing the API and the fix was always a server-side edit. So, I am lead to believe that this error is not my fault.</p>
# <p>I can get other errors if I use incorrect credentials, bad XML formatting, etc. I can successfully use the SOAP &quot;Login&quot; request for this API, but the all the getter SOAP requests for this API throw this same error</p>
# <p>I don't believe this is an account permission error because my I was told by my superiors the account had the permissions required. Is there something I can do on my end to resolve this error?</p>
# <p>My SOAP Body:</p>
# <pre><code>&lt;?xml version=&quot;1.0&quot; encoding=&quot;utf-8&quot; ?&gt;
# &lt;soap:Envelope xmlns:xsi=&quot;http://www.w3.org/2001/XMLSchema-instance&quot; xmlns:xsd=&quot;http://www.w3.org/2001/XMLSchema&quot; xmlns:soap=&quot;http://schemas.xmlsoap.org/soap/envelope/&quot;&gt;
#     &lt;soap:Header&gt;
#         &lt;AuthenticationHeader xmlns=&quot;http://url/omitted/&quot;&gt;
#             &lt;userName&gt;{{username}}&lt;/userName&gt;
#             &lt;userPassword&gt;{{password}}&lt;/userPassword&gt;
#         &lt;/AuthenticationHeader&gt;
#     &lt;/soap:Header&gt;
#     &lt;soap:Body&gt;
#         &lt;GetDeviceCommands xmlns=&quot;http://url/omitted/&quot;&gt;
#             &lt;datagateId&gt;{{datagateid}}&lt;/datagateId&gt;
#         &lt;/GetDeviceCommands&gt;
#     &lt;/soap:Body&gt;
# &lt;/soap:Envelope&gt;
# </code></pre>
# <p>The Error:</p>
# <pre><code>&lt;soap:Fault&gt;
#     &lt;faultcode&gt;soap:Server&lt;/faultcode&gt;
#     &lt;faultstring&gt;Server was unable to process request. ---&amp;gt; Request for principal permission failed.&lt;/faultstring&gt;
#     &lt;detail /&gt;
# &lt;/soap:Fault&gt;
# </code></pre>
# <p>I get the same error when I make the request from a c# console app. Confirmed has nothing to do with postman.</p>
# <pre><code>System.AggregateException: 'constructorArgs[0]Server was unable to process
# request. ---&gt; Request for principal permission failed.)'
#
# Inner Exception
# FaultException: Server was unable to process request. ---&gt; Request for principal permission failed.
# </code></pre>
#
#
# Display Name: user716255
# Profile Image URL: https://www.gravatar.com/avatar/4057228c332e51257f3041ab597c7c73?s=128&d=identicon&r=PG
# Post ID: 63237383
# Post Body: <p>I am trying to count the number of times [Tracking id] &amp; [Tracking ID1] appear in a table.</p>
# <p><a href="https://i.stack.imgur.com/5359e.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/5359e.png" alt="enter image description here" /></a></p>
# <p>The result should look like this.</p>
# <p><a href="https://i.stack.imgur.com/krIcf.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/krIcf.png" alt="enter image description here" /></a></p>
# <p>This works great when I use a group by function.</p>
# <pre><code>select [Group], datename(month,[date]) as Month, count([Tracking ID]) + count([Tracking ID1]) as [Number of Record]
# from   [Table]
# group by
#     [Group],
#     datename(month,[date])
# </code></pre>
# <p>I need to use a pivot function. How do I modify the code below to get the desired results</p>
# <pre><code>select *
# from
#     (
# select
#     [Group], datename(month,[date]) as Month, (count([Tracking ID])over () + count([Tracking ID1]) over () ) as [Number of Record]
# From
#     [Table]
# ) sourcetbl
# pivot
#     (count([Number of Record])
# for [Month] in ([June], [July])
# ) as pivotTable;
# </code></pre>
# <p>Currently, my query returns 2 instead of 4.</p>
# <p><a href="https://i.stack.imgur.com/YbQcW.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/YbQcW.png" alt="enter image description here" /></a></p>
#
#
# Display Name: Kevko
# Profile Image URL: https://lh5.googleusercontent.com/-ebmDzzMuzRQ/AAAAAAAAAAI/AAAAAAAABNM/OuhnEXZ97-k/photo.jpg?sz=128
# Post ID: 63235230
# Post Body: <p>I want to get the returned data whenever fetching is done, because the correct timestamp will be there after fully fetching however the function will return the link with an empty timestamp instead of the latest timestamp of all the data.</p>
# <pre><code>async function pushData(url) {
#   let settings = { method: &quot;Get&quot; };
#   let timestamp = &quot;&quot;;
#   let i = 0;
#
#   fetch(url, settings)
#       .then(res =&gt; res.json())
#       .then((json) =&gt; {
#         json.forEach(function (object) {
#           console.log(object);
#           i++;
#         });
#         timestamp = json[i-1].timestamp;
#       });
#
#   return await 'https://www.bitmex.com/api/v1/trade?count=1000&amp;symbol=XBTUSD&amp;startTime=' + timestamp;
# }
#
# var test = pushData('https://www.bitmex.com/api/v1/trade?count=1000&amp;symbol=XBTUSD');
# console.log(test);
# </code></pre>
#
#
# Display Name: nikolifish
# Profile Image URL: https://www.gravatar.com/avatar/3aae252b0cef6df16e7b8c2020b050da?s=128&d=identicon&r=PG
# Post ID: 63233712
# Post Body: <p>I'm trying to add text with small caps in the Word API.  I read through the paragraph documentation and saw it wasn't implemented using the <code>insertParagraph</code> method.  I was hoping to circumvent that by using either <code>insertHtml</code> or <code>insertOoxml</code>.</p>
# <p>Right now, my current attempt is to use insertHtml to try to insert the following paragraph</p>
# <pre class="lang-js prettyprint-override"><code>range.insertHtml('text &lt;i&gt;inserted&lt;/i&gt; &lt;p style=&quot;font-variant: small-caps&quot;&gt; With &lt;/p&gt; &lt;b&gt;insert  &lt;p&gt;Html&lt;/b&gt; &lt;/p&gt; Hello!!!  ', Word.InsertLocation.before);
# </code></pre>
# <p>It seems the office api is stripping that out.  I tried changing the font family with the same code and that worked fine.</p>
# <p>Does anyone know a work around to this?</p>
#
#
# Display Name: Tim
# Profile Image URL: https://i.stack.imgur.com/8htyd.jpg?s=128&g=1
# Post ID: 63235455
# Post Body: <p>With persistence enabled in <code>broker.xml</code> and when <code>-Xms</code> &amp; <code>-Xmx</code> are set to 4GB and <code>global-max-size</code> set to default 200Mb (most of the setting were just created by the Artemis <code>create</code> command) I am getting the below exceptions either within a day or three based on the rate of data processed. Configuration is similar to <a href="https://stackoverflow.com/questions/63235169/apache-artemis-logs-amq212037-connection-failure-and-connection-reset-by-peer">this post</a>.</p>
# <pre><code>2020-08-03 02:25:58,969 WARN  [org.apache.activemq.artemis.core.server] AMQ222033: Page file 000000005.page had incomplete records at position 9,259,622 at record number 4,224
# 2020-08-03 02:31:19,390 WARN  [org.apache.activemq.artemis.core.server] AMQ222288: Page 5, message 4,224 could not be found on offset 9,259,622, with starting message 4,224. This represents a logic error or inconsistency on the data, and the system will try once again from the beggining of the page file.
# 2020-08-03 03:05:10,331 WARN  [org.apache.activemq.artemis.utils.actors.OrderedExecutor] Java heap space: java.lang.OutOfMemoryError: Java heap space
#
# </code></pre>
# <p>I was able to confirm the heap was 100%.</p>
# <pre><code>Heap Usage:
# G1 Heap:
#    regions  = 2048
#    capacity = 4294967296 (4096.0MB)
#    used     = 4285561048 (4087.0295028686523MB)
#    free     = 9406248 (8.970497131347656MB)
#    99.78099372237921% used
# G1 Young Generation:
# Eden Space:
#    regions  = 0
#    capacity = 8388608 (8.0MB)
#    used     = 0 (0.0MB)
#    free     = 8388608 (8.0MB)
#    0.0% used
# Survivor Space:
#    regions  = 0
#    capacity = 0 (0.0MB)
#    used     = 0 (0.0MB)
#    free     = 0 (0.0MB)
#    0.0% used
# G1 Old Generation:
#    regions  = 2048
#    capacity = 4286578688 (4088.0MB)
#    used     = 4285561048 (4087.0295028686523MB)
#    free     = 1017640 (0.9704971313476562MB)
#    99.97625985490832% used
#
# 14525 interned Strings occupying 1435888 bytes.
#
# </code></pre>
# <p>Using Artemis version 2.13.0. VM is a 2 core Linux machine with 7 GB RAM. I had disabled the persistence. Also another observation is the RES size is growing gradually when I use the top command.</p>
# <p>Client configuration: (using camel and activeMq JMS component)</p>
# <pre><code>  &lt;bean id=&quot;conxnFactory&quot; class=&quot;org.apache.activemq.ActiveMQConnectionFactory&quot;&gt;
#       &lt;property name=&quot;brokerURL&quot; value=&quot;tcp://domain-name:port&quot; /&gt;
#     &lt;/bean&gt;
#
#     &lt;bean id=&quot;pooledconxnFactory&quot; class=&quot;org.apache.activemq.pool.PooledConnectionFactory&quot; init-method=&quot;start&quot; destroy-method=&quot;stop&quot;&gt;
#       &lt;property name=&quot;maxConnections&quot; value=&quot;5&quot; /&gt;
#       &lt;property name=&quot;connectionFactory&quot; ref=&quot;conxnFactory&quot; /&gt;
#     &lt;/bean&gt;
#
#     &lt;bean id=&quot;config&quot; class=&quot;org.apache.camel.component.jms.JmsConfiguration&quot;&gt;
#       &lt;property name=&quot;connectionFactory&quot; ref=&quot;pooledconxnFactory&quot; /&gt;
#       &lt;property name=&quot;concurrentConsumers&quot; value=&quot;5&quot; /&gt;
#     &lt;/bean&gt;
#
#     &lt;bean id=&quot;jmsqueue&quot; class=&quot;org.apache.activemq.camel.component.ActiveMQComponent&quot;&gt;
#       &lt;property name=&quot;configuration&quot; ref=&quot;config&quot; /&gt;
#     &lt;/bean&gt;
#
#     &lt;camelContext id=&quot;camel&quot; xmlns=&quot;http://camel.apache.org/schema/spring&quot;&gt;
#       &lt;endpoint id=&quot;inputQueue&quot; uri=&quot;jmsqueue:queue:dataqueue1&quot; /&gt;
#
#       &lt;route&gt;
#         &lt;from uri=&quot;ref:inputQueue&quot; /&gt;
# ...
# </code></pre>
# <p>I was not able to get the heapdump, but there was a hs_err_pid file generated.</p>
# <pre><code>...
# Other Threads:
#   0x00007f9d10282000 VMThread [stack: 0x00007f9d147a4000,0x00007f9d148a4000] [id=68249]
#   0x00007f9d102d2800 WatcherThread [stack: 0x00007f9d00f00000,0x00007f9d01000000] [id=68257]
#
# =&gt;0x00007f9d10023000 (exited) GCTaskThread [stack: 0x00007f9d16eaa000,0x00007f9d16faa000] [id=68242]
#
# VM state:at safepoint (normal execution)
#
# VM Mutex/Monitor currently owned by a thread:  ([mutex/lock_event])
# [0x00007f9d10007bd0] Threads_lock - owner thread: 0x00007f9d10282000
# [0x00007f9d100080d0] Heap_lock - owner thread: 0x00007f9cf421d800
#
# Heap:
#  garbage-first heap   total 2097152K, used 2088898K [0x0000000080000000, 0x0000000080104000, 0x0000000100000000)
#   region size 1024K, 0 young (0K), 0 survivors (0K)
#  Metaspace       used 46102K, capacity 46842K, committed 47408K, reserved 1091584K
#   class space    used 5086K, capacity 5295K, committed 5424K, reserved 1048576K
#
# Heap Regions: (Y=young(eden), SU=young(survivor), HS=humongous(starts), HC=humongous(continues), CS=collection set, F=free, TS=gc time stamp, PTAMS=previous top-at-mark-start, NTAMS=next top-at-mark-start)
# AC   0  O    TS     0 PTAMS 0x0000000080000000 NTAMS 0x0000000080000000 space 1024K,  99% used [0x0000000080000000, 0x0000000080100000)
# AC   0  O    TS     0 PTAMS 0x0000000080100000 NTAMS 0x0000000080100000 space 1024K,  99% used [0x0000000080100000, 0x0000000080200000)
# AC   0  O    TS     0 PTAMS 0x0000000080200000 NTAMS 0x0000000080200000 space 1024K,  99% used [0x0000000080200000, 0x0000000080300000)
# AC   0  O    TS     0 PTAMS 0x0000000080300000 NTAMS 0x0000000080300000 space 1024K,  99% used [0x0000000080300000, 0x0000000080400000)
# AC   0  O    TS     0 PTAMS 0x0000000080400000 NTAMS 0x0000000080400000 space 1024K,  99% used [0x0000000080400000, 0x0000000080500000)
# AC   0  O    TS     0 PTAMS 0x0000000080500000 NTAMS 0x0000000080500000 space 1024K,  99% used [0x0000000080500000, 0x0000000080600000)
# AC   0  O    TS     0 PTAMS 0x0000000080600000 NTAMS 0x0000000080600000 space 1024K,  98% used [0x0000000080600000, 0x0000000080700000)
# ....
# ...
# Deoptimization events (10 events):
# Event: 26931.254 Thread 0x00007f9ce0031000 Uncommon trap: reason=bimorphic action=maybe_recompile pc=0x00007f9d01589b58 method=java.util.AbstractCollection.toArray()[Ljava/lang/Object; @ 1
# Event: 26940.746 Thread 0x00007f9cbc4e7800 Uncommon trap: reason=class_check action=maybe_recompile pc=0x00007f9d01c69704 method=org.apache.activemq.artemis.core.remoting.impl.netty.ActiveMQChannelHandler.lambda$channelInactive$0(Lio/netty/channel/ChannelHandlerContext;)V @ 13
# Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: reason=unstable_if action=reinterpret pc=0x00007f9d01f98b44 method=org.apache.activemq.artemis.utils.UUID.toString()Ljava/lang/String; @ 4
# Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: reason=class_check action=maybe_recompile pc=0x00007f9d02a77920 method=org.apache.activemq.artemis.core.server.impl.QueueImpl$ConsumerHolder.getPriority()I @ 4
# Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: reason=class_check action=maybe_recompile pc=0x00007f9d011dcd40 method=org.apache.activemq.artemis.core.server.impl.QueueImpl$ConsumerHolder.getPriority()I @ 4
# Event: 27003.328 Thread 0x00007f9cbc4e7800 Uncommon trap: reason=unstable_if action=reinterpret pc=0x00007f9d01ba2a84 method=java.lang.AbstractStringBuilder.append(I)Ljava/lang/AbstractStringBuilder; @ 16
# Event: 27142.215 Thread 0x0000000001333000 Uncommon trap: reason=unstable_if action=reinterpret pc=0x00007f9d02660584 method=java.net.InetAddress.toString()Ljava/lang/String; @ 16
# Event: 27142.216 Thread 0x0000000001333000 Uncommon trap: reason=class_check action=maybe_recompile pc=0x00007f9d029b9650 method=org.apache.activemq.artemis.utils.ActiveMQThreadPoolExecutor$ThreadPoolQueue.offer(Ljava/lang/Object;)Z @ 2
# Event: 29769.075 Thread 0x00007f9d10b14000 Uncommon trap: reason=unstable_if action=reinterpret pc=0x00007f9d0267c37c method=java.util.concurrent.FutureTask.runAndReset()Z @ 115
# Event: 30265.745 Thread 0x00007f9d106f3800 Uncommon trap: reason=unstable_if action=reinterpret pc=0x00007f9d0267c418 method=java.util.concurrent.FutureTask.run()V @ 66
#
# Internal exceptions (10 events):
# Event: 31469.887 Thread 0x00007f9cf4007800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31486.605 Thread 0x00007f9cf4007800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31504.901 Thread 0x00007f9cf4007800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31522.574 Thread 0x00007f9cf4007800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31538.769 Thread 0x00007f9d110a4000 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31556.358 Thread 0x00007f9d110a4000 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31574.508 Thread 0x00007f9d110a4000 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31590.147 Thread 0x00007f9d10e37800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31606.743 Thread 0x00007f9d10e37800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004efc8) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/gc_interface/collectedHeap.inline.hpp, line 159]
# Event: 31606.743 Thread 0x00007f9d10e37800 Exception &lt;a 'java/lang/OutOfMemoryError'&gt; (0x000000008004f068) thrown at [/HUDSON/workspace/8-2-build-linux-amd64/jdk8u131/8869/hotspot/src/share/vm/runtime/deoptimization.cpp, line 790]
#
# Events (10 events):
# Event: 31590.147 Executing VM operation: G1CollectForAllocation done
# Event: 31590.148 Executing VM operation: G1IncCollectionPause
# Event: 31590.167 Executing VM operation: G1IncCollectionPause done
# Event: 31590.167 Executing VM operation: G1IncCollectionPause
# Event: 31590.175 Executing VM operation: G1IncCollectionPause done
# Event: 31590.188 Executing VM operation: G1CollectForAllocation
# Event: 31606.743 Executing VM operation: G1CollectForAllocation done
# Event: 31606.743 Thread 0x00007f9d10e37800 DEOPT PACKING pc=0x00007f9d021831a8 sp=0x00007f9ce46b4f00
# Event: 31606.743 Thread 0x00007f9d10e37800 DEOPT UNPACKING pc=0x00007f9d01047373 sp=0x00007f9ce46b4be0 mode 1
# Event: 31606.749 Executing VM operation: G1IncCollectionPause
# ..
# </code></pre>
# Update:
# <p>Not able to get the heap dump, as the broker instance hangs after logging the below message in logs</p>
# <pre><code>2020-08-07 00:17:32,835 WARNING [sun.rmi.transport.tcp] RMI TCP Accept-0: accept loop for ServerSocket[addr=localhost/127.0.0.1,localport=33088] throws: java.lang.OutOfMemoryError: Java heap space
#
# 2020-08-07 00:17:49,675 WARN  [org.apache.activemq.artemis.utils.actors.OrderedExecutor] Java heap space: java.lang.OutOfMemoryError: Java heap space
#         at org.apache.activemq.artemis.core.paging.impl.Page.readMessage(Page.java:208) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageReader.getMessage(PageReader.java:94) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl.internalGetNext(PageSubscriptionImpl.java:432) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl.access$2200(PageSubscriptionImpl.java:67) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.moveNext(PageSubscriptionImpl.java:1353) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.next(PageSubscriptionImpl.java:1318) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.tryNext(PageSubscriptionImpl.java:1445) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.paging.cursor.impl.PageSubscriptionImpl$CursorIterator.hasNext(PageSubscriptionImpl.java:1461) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.QueueImpl.checkDepage(QueueImpl.java:2989) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.QueueImpl.deliverAsync(QueueImpl.java:1243) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.QueueImpl.deliverAsync(QueueImpl.java:1237) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.ServerConsumerImpl.forceDelivery(ServerConsumerImpl.java:1154) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.ServerConsumerImpl.promptDelivery(ServerConsumerImpl.java:1146) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.ServerConsumerImpl.setStarted(ServerConsumerImpl.java:755) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.ServerSessionImpl.setStarted(ServerSessionImpl.java:2013) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.server.impl.ServerSessionImpl.start(ServerSessionImpl.java:1667) [artemis-server-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.protocol.openwire.amq.AMQSession.start(AMQSession.java:269) [artemis-openwire-protocol-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection.addConsumer(OpenWireConnection.java:908) [artemis-openwire-protocol-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection$CommandProcessor.processAddConsumer(OpenWireConnection.java:1194) [artemis-openwire-protocol-2.13.0.jar:2.13.0]
#         at org.apache.activemq.command.ConsumerInfo.visit(ConsumerInfo.java:351) [activemq-client-5.14.5.jar:5.14.5]
#         at org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection.act(OpenWireConnection.java:322) [artemis-openwire-protocol-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.core.protocol.openwire.OpenWireConnection$$Lambda$124/267018299.onMessage(Unknown Source)
#         at org.apache.activemq.artemis.utils.actors.Actor.doTask(Actor.java:33) [artemis-commons-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.utils.actors.ProcessorBase.executePendingTasks(ProcessorBase.java:65) [artemis-commons-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.utils.actors.ProcessorBase$$Lambda$35/656479172.run(Unknown Source)
#         at org.apache.activemq.artemis.utils.actors.OrderedExecutor.doTask(OrderedExecutor.java:42) [artemis-commons-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.utils.actors.OrderedExecutor.doTask(OrderedExecutor.java:31) [artemis-commons-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.utils.actors.ProcessorBase.executePendingTasks(ProcessorBase.java:65) [artemis-commons-2.13.0.jar:2.13.0]
#         at org.apache.activemq.artemis.utils.actors.ProcessorBase$$Lambda$35/656479172.run(Unknown Source)
#         at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142) [rt.jar:1.8.0_131]
#         at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617) [rt.jar:1.8.0_131]
#         at org.apache.activemq.artemis.utils.ActiveMQThreadFactory$1.run(ActiveMQThreadFactory.java:118) [artemis-commons-2.13.0.jar:2.13.0]
# </code></pre>
# <p>With the persistence flag as false in broker.xml, the heap issue occurred only once. (as mentioned the logs above)</p>
# <p>Enabling <code>artemis.profile</code> to log oom_heapdump.hprof didn't log any info but exception with Thread dump info.</p>
# <p>The below message is also noticed frequently in the logs.</p>
# <pre><code>2020-08-09 17:51:03,484 WARN  [org.apache.activemq.artemis.core.server] AMQ222038: Starting paging on address 'ActiveMQ.Advisory.TempQueue'; size is currently: 2,147,471,789 bytes; max-size-bytes: -1; global-size-bytes: 2,147,486,900
# </code></pre>
# <p>The clients (consumer) uses OPENWIRE using activemq-5.13 client jar. From the broker console, the producer use CORE protocol.</p>
# <p>Jvisual VM for Broker running straight 20 hrs</p>
# <p><a href="https://i.stack.imgur.com/euwWm.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/euwWm.png" alt="visualVM monitor" /></a></p>
# <p>I enabled the JAVA_ARGS to print the OOM trace a 7 GB file got generated, below is the analysis using Eclipse MAT tool.</p>
# <p><a href="https://i.stack.imgur.com/TkKcJ.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/TkKcJ.png" alt="histogram of heap" /></a></p>
# <p>1.2G shallow heap consumption by <code>org.apache.activemq.artemis.core.paging.cursor.impl.PagePosistionImpl</code>.</p>
# <p>From the Docs, when address-full-policy is set to PAGE that is the time broker starts appending to page. Other values are DROP and BLOCK (blocks producer, until memory is freed). I planning to use address-full-policy to BLOCK to see if the OOM issue exists.</p>
#
#
# Display Name: Tulon
# Profile Image URL: https://i.stack.imgur.com/2MOY0.png?s=128&g=1
# Post ID: 63237587
# Post Body: <p>Whenever I tried to add <code>photos</code> permission on my scope it always giving this message while login:</p>
# <p><a href="https://i.stack.imgur.com/BGcIo.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/BGcIo.png" alt="enter image description here" /></a></p>
# <p>Without <code>photos</code> permission it is working perfectly. Here is my code:</p>
# <pre><code>document.getElementById('fb-login-btn').addEventListener('click', function() {
#    FB.login((response) =&gt; {
#      statusChangeCallback(response);
#    }, {scope: 'public_profile,photos', return_scopes: true}); //{scope: 'public_profile,email', return_scopes: true});
#  }, false);
# </code></pre>
# <p>I don't think the problem lies in code, because the same problem also occurred with default <code>facebook login button</code> as well, when I added <code>photos</code> permission. Any suggestions?</p>
#
#
# Display Name: Andreas
# Profile Image URL: https://www.gravatar.com/avatar/c38f6255df694b842b5f0b588946beee?s=128&d=identicon&r=PG
# Post ID: 63244392
# Post Body: <p>we have the following setup, which seems to override each other:</p>
# <ul>
# <li>following the tinyMCE angular <a href="https://www.tiny.cloud/docs/integrations/angular/#usingwithreactiveforms" rel="nofollow noreferrer">integration docs</a></li>
# <li>angular reactive forms (angular 9), which are generated dynamicaly based on a type, eg. <strong>html</strong>:</li>
# </ul>
# <pre class="lang-js prettyprint-override"><code>private generateFormConfig() {
#     const formConfig = {};
#
#     // ...
#
#     formConfig[controlId] = new FormControl(
#         value,
#         Validators.compose(formValidators)
#     );
#
#     // ...
#     this.form = this.formBuilder.group(formConfig);
# }
# </code></pre>
# <ul>
# <li>the form is then rendered inside a ionic modal component also with a dynamic *ngFor:</li>
# </ul>
# <pre class="lang-html prettyprint-override"><code>&lt;ng-template #formItems let-definition=&quot;definition&quot; let-data=&quot;data&quot; let-path=&quot;path&quot; let-errors=&quot;errors&quot;&gt;
#   &lt;div [formGroup]=&quot;form&quot;&gt;
#     &lt;div *ngFor=&quot;let formItemConf of definition&quot;&gt;
#       &lt;div [ngSwitch]=&quot;formItemConf.input&quot; [class]=&quot;'input-wrp input-wrp--' + formItemConf.input&quot;&gt;
#
#         &lt;ion-input *ngSwitchDefault [type]=&quot;formItemConf.type&quot; [formControlName]=&quot;getFormItemId(path, formItemConf.id)&quot; class=&quot;form-control&quot;&gt;&lt;/ion-input&gt;
#
#         &lt;editor *ngSwitchCase=&quot;'html'&quot; [id]=&quot;formItemConf.id&quot; [init]=&quot;{
#               height: 300,
#               resize: true,
#               convert_urls: false,
#               menubar: 'edit view format',
#               plugins: 'paste link lists code',
#               toolbar: 'undo redo |  formatselect bold italic underline | bullist numlist | link | alignleft aligncenter alignright alignjustify | forecolor backcolor | paste removeformat | code',
#
#               table_appearance_options: false,
#               table_resize_bars: false,
#               table_style_by_css: true,
#
#               paste_data_images: true
#             }&quot; [initialValue]=&quot;getFormValue(formItemConf, data)&quot; [formControlName]=&quot;getFormItemId(path, formItemConf.id)&quot;&gt;
#         &lt;/editor&gt;
#
#         &lt;ion-select *ngSwitchCase=&quot;'select'&quot; [formControlName]=&quot;getFormItemId(path, formItemConf.id)&quot; class=&quot;form-control&quot;&gt;
#           &lt;ion-select-option *ngFor=&quot;let option of formItemConf.options&quot; [value]=&quot;option.value&quot;&gt;{{option.label | translate}}&lt;/ion-select-option&gt;
#         &lt;/ion-select&gt;
#
#         &lt;ion-checkbox *ngSwitchCase=&quot;'boolean'&quot; [formControlName]=&quot;getFormItemId(path, formItemConf.id)&quot;&gt;&lt;/ion-checkbox&gt;
#
#         &lt;!-- ... and so on --&gt;
#
#         &lt;div class=&quot;error&quot; *ngIf=&quot;hasError(errors, formItemConf.id)&quot;&gt;{{errors[formItemConf.id]}}&lt;/div&gt;
#
#       &lt;/div&gt;
#     &lt;/div&gt;
#   &lt;/div&gt;
# &lt;/ng-template&gt;
# </code></pre>
# <p>This works all spotless, but if we try to use the <strong>link</strong> or <strong>code</strong> plugin of tinymce, which are using modals by itself, it is impossible to edit the content. Th reason as far as I can see is, that the underlying inputs are hijacking the form focus, if I try to click an input:</p>
# <p><a href="https://i.stack.imgur.com/8aIMm.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/8aIMm.png" alt="enter image description here" /></a></p>
# <p>The tinyMCE overlay inputs become unusable by this.</p>
# <p>Any idea what the reason could be and how to fix it, would be higly appreciated :) Maybe this is a &quot;feature&quot; of angular reactive forms and can be dissabled?</p>
#
#
# Display Name: Ahmed Ghrib
# Profile Image URL: https://lh4.googleusercontent.com/-9YrXTDQImsU/AAAAAAAAAAI/AAAAAAAAELQ/WJsZP3aPFDM/photo.jpg?sz=128
# Post ID: 63249690
# Post Body: <p>I'm just getting started with Xcode and iOS development. I am supposed to reproduce an iOS project on a tvOS.
# One of the frameworks is <a href="https://github.com/jessesquires/JSQCoreDataKit" rel="nofollow noreferrer">JSQCoreDataKit</a></p>
# <p>In the original iOS project, this framework exists in two places:<br />
# <strong>PODS:</strong>.<br />
# <a href="https://i.stack.imgur.com/fJpIj.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/fJpIj.png" alt="enter image description here" /></a><br />
# <strong>FRAMEWORKS</strong>.<br />
# <a href="https://i.stack.imgur.com/Z9GIs.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/Z9GIs.png" alt="enter image description here" /></a></p>
# <p>I installed the framework following the manual instructions in this <a href="https://github.com/jessesquires/JSQCoreDataKit" rel="nofollow noreferrer">link</a>.<br />
# So in the new project, it is installed as a normal framework:<br />
# <a href="https://i.stack.imgur.com/KlC8t.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/KlC8t.png" alt="enter image description here" /></a>.</p>
# <p>The problem I have faced is : Some of the code that works in the original project, relies on a code that is defined in the PODS folder:<br />
# <strong>EXAMPLE:</strong></p>
# <pre><code>func saveChanges() {
#     stack.mainContext.performAndWait {
#         saveContext(self.stack.mainContext)
#     }
# }
# </code></pre>
# <p><strong>saveContext</strong> function exists in:</p>
# <p><a href="https://i.stack.imgur.com/teXgA.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/teXgA.png" alt="enter image description here" /></a></p>
# <p>And this is its definition(just in case):</p>
# <pre><code>public func saveContext(_ context: NSManagedObjectContext, wait: Bool = true, completion: ((SaveResult) -&gt; Void)? = nil) {
#     let block = {
#         guard context.hasChanges else { return }
#         do {
#             try context.save()
#             completion?(.success)
#         }
#         catch {
#             completion?(.failure(error as NSError))
#         }
#     }
#     wait ? context.performAndWait(block) : context.perform(block)
# }
# </code></pre>
# <p>So while in the original project where Pods exists, this works fine.<br />
# In the new project, where it doesn't exist, and the framework is installed manually, I get this error:</p>
# <blockquote>
# <p>Use of unresolved identifier 'saveContext'</p>
# </blockquote>
# <p>But, the framework gets imported successfully with no errors :</p>
# <pre><code>import JSQCoreDataKit
# </code></pre>
# <p>One last thing, adding the framework with the manual method described in this <a href="https://github.com/jessesquires/JSQCoreDataKit" rel="nofollow noreferrer">link</a> doesn't make it appear in here:<br />
# <a href="https://i.stack.imgur.com/5T75q.png" rel="nofollow noreferrer"><img src="https://i.stack.imgur.com/5T75q.png" alt="enter image description here" /></a></p>
#
#
# Display Name: Siddhesh DilipKumar
# Profile Image URL: https://lh4.googleusercontent.com/-BiwcTfc3e-w/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucmdeMfy8TRUKoMkp0ka-Oa2Zotk3A/photo.jpg?sz=128
# Post ID: 63239647
# Post Body: <p>Recently, I started working on the angular application and stuck with unique problem which is related to unit testing of input fields of the application.Please, keep this in mind that I didnt write the whole application and test cases but rather started working on the existing one.</p>
# <p>Following code snippets will help to elaborate the problem more preciously.</p>
# <p>trip-leg component.html</p>
# <pre><code>  &lt;mat-card class=&quot;trip-leg-container&quot; id=&quot;tripLegContainer{{ index + 1 }}&quot;&gt;
#   &lt;h3 class=&quot;trip-leg-header&quot;&gt;Leg {{ index + 1 }}&lt;/h3&gt;
#   &lt;form [formGroup] = &quot;triplegForm&quot;&gt;
#     &lt;mat-form-field appearance=&quot;outline&quot;class=&quot;w-25 d-block&quot;&gt;
#       &lt;mat-label class=&quot;trip-origin-label&quot;&gt;{{ ORIGIN_LABEL }}&lt;/mat-label&gt;
#       &lt;input
#           type=&quot;text&quot;
#           matInput
#           formControlName = 'triplegOriginControl'
#           [matAutocomplete]=&quot;autoTripLegOrigin&quot;
#           class = 'trip-origin-input'
#       /&gt;
#       &lt;mat-autocomplete #autoTripLegOrigin=&quot;matAutocomplete&quot;&gt;
#         &lt;mat-option
#           *ngFor=&quot;let option of triplegOriginOptions | async&quot;
#           [value]=&quot;option&quot;
#         &gt;
#           {{ option }}
#         &lt;/mat-option&gt;
#       &lt;/mat-autocomplete&gt;
#     &lt;/mat-form-field&gt;
#     &lt;mat-form-field appearance=&quot;outline&quot;class=&quot;w-25 d-block&quot;&gt;
#       &lt;mat-label class=&quot;trip-destination-label&quot;&gt;{{
#         DESTINATION_LABEL
#       }}&lt;/mat-label&gt;
#       &lt;input
#           type=&quot;text&quot;
#           matInput
#           formControlName = 'triplegDestinationControl'
#           [matAutocomplete]=&quot;autoTripLegDestination&quot;
#           class = 'trip-destination-input'
#       /&gt;
#       &lt;mat-autocomplete #autoTripLegDestination=&quot;matAutocomplete&quot;&gt;
#         &lt;mat-option
#           *ngFor=&quot;let option of triplegDestinationOptions | async&quot;
#           [value]=&quot;option&quot;
#         &gt;
#           {{ option }}
#         &lt;/mat-option&gt;
#       &lt;/mat-autocomplete&gt;
#     &lt;/mat-form-field&gt;
#  &lt;/form&gt;
#   &lt;div&gt;
#     &lt;mat-form-field appearance=&quot;outline&quot; class=&quot;w-25&quot;&gt;
#       &lt;mat-label class=&quot;vessel-length-label&quot;&gt;{{
#         VESSEL_LENGTH_LABEL
#       }}&lt;/mat-label&gt;
#       &lt;input
#         matInput
#         [(ngModel)]=&quot;leg.vesselLength&quot;
#         (ngModelChange)=&quot;this.vesselInputChange()&quot;
#         class=&quot;trip-vessel-length-input&quot;
#       /&gt;
#     &lt;/mat-form-field&gt;
#     &lt;mat-form-field appearance=&quot;outline&quot; class=&quot;ml-20 w-25&quot;&gt;
#       &lt;mat-label class=&quot;vessel-type-label&quot;&gt;{{ VESSEL_TYPE_LABEL }}&lt;/mat-label&gt;
#       &lt;input
#         matInput
#         [(ngModel)]=&quot;leg.vesselType&quot;
#         (ngModelChange)=&quot;this.vesselInputChange()&quot;
#         class=&quot;trip-vessel-type-input&quot;
#       /&gt;
#     &lt;/mat-form-field&gt;
#     &lt;mat-form-field appearance=&quot;outline&quot; class=&quot;ml-20 w-25&quot;&gt;
#       &lt;mat-label class=&quot;vessel-status-label&quot;&gt;{{ LOAD_STATUS_LABEL }}&lt;/mat-label&gt;
#       &lt;input
#         matInput
#         [(ngModel)]=&quot;leg.vesselStatus&quot;
#         (ngModelChange)=&quot;this.vesselInputChange()&quot;
#         class=&quot;trip-load-status-input&quot;
#       /&gt;
#     &lt;/mat-form-field&gt;
#   &lt;/div&gt;
#   &lt;div&gt;
#     &lt;mat-form-field appearance=&quot;outline&quot; class=&quot;w-25 d-block&quot;&gt;
#       &lt;mat-label class=&quot;vendor-label&quot;&gt;{{ VENDOR_LABEL }}&lt;/mat-label&gt;
#       &lt;input matInput [(ngModel)]=&quot;leg.vendor&quot; class=&quot;trip-vendor-input&quot; /&gt;
#     &lt;/mat-form-field&gt;
#   &lt;/div&gt;
#   &lt;div&gt;
#     &lt;button
#       *ngIf=&quot;tripLegsLength &gt; 1&quot;
#       mat-icon-button
#       aria-label=&quot;remove leg&quot;
#       class=&quot;remove-trip-leg-button&quot;
#       (click)=&quot;removeTripLeg()&quot;
#     &gt;
#       &lt;mat-icon&gt;delete&lt;/mat-icon&gt;REMOVE LEG
#     &lt;/button&gt;
#   &lt;/div&gt;
# &lt;/mat-card&gt;
# </code></pre>
# <p>trip-leg component.ts</p>
# <pre><code>@Component({
#   selector: 'app-trip-leg',
#   templateUrl: './trip-leg.component.html',
#   styleUrls: ['./trip-leg.component.scss']
# })
# export class TripLegComponent {
#
#   triplegForm: FormGroup;
#
#   public facilityList:Facility[];
#
#   triplegOriginOptions:Observable&lt;any[]&gt;;
#   triplegDestinationOptions: Observable&lt;any[]&gt;;
#
#   locationArray:any[] = [];
#
#
#   @Input() leg: TripLeg;
#   @Input() index: number;
#   @Input() tripLegsLength: number;
#
#   @ViewChild(MatAutocomplete, { static: false })
# matAutocomplete:MatAutocomplete;
#
#   @Output() tripLegIndexEmitter: EventEmitter&lt;number&gt; = new EventEmitter&lt;number&gt;();
#   @Output() deleteAtIndex: EventEmitter&lt;number&gt; = new EventEmitter&lt;number&gt;();
#
#   ORIGIN_LABEL = 'Origin';
#   DESTINATION_LABEL = 'Destination';
#   VESSEL_LENGTH_LABEL = 'Vessel Length';
#   VESSEL_TYPE_LABEL = 'Vessel Type';
#   LOAD_STATUS_LABEL = 'Load Status';
#   VENDOR_LABEL = 'Vendor';
#
#   constructor(
#     private http:HttpClient,
#     private facilityService:FacilityService
#       ) {}
#
# ngOnInit():void {
#   this.triplegForm = new FormGroup({
#     &quot;triplegOriginControl&quot;: new FormControl(),
#     &quot;triplegDestinationControl&quot;: new FormControl()
#   })
#
#   this.triplegForm.get('triplegOriginControl').valueChanges.subscribe(
#     (value) =&gt; this.leg.originId = value
#   );
#
#   this.triplegForm.get('triplegDestinationControl').valueChanges.subscribe(
#     (value) =&gt; this.leg.destinationId = value
#   );
#
#   this.triplegOriginOptions= this.triplegForm.get('triplegOriginControl').valueChanges.pipe(
#   startWith(&quot;&quot;),
#   map((value) =&gt; this._filter(value)));
#
#   this.triplegDestinationOptions= this.triplegForm.get('triplegDestinationControl').valueChanges.pipe(
#   startWith(&quot;&quot;),
#   map((value) =&gt; this._filter(value)));
#
#    this.fetchData();
#   }
#
#   //filtering data for autocomplete feature
#   private _filter(value:string):string[] {
#   return this.locationArray.filter((opt) =&gt;
#   opt.toLowerCase().includes(value)
#     );
#   }
#
#   //autocomplete the origin input box based on user input with tab button
# // chooseFirstOption():void {
# //   this.matAutocomplete.options.first.select();
# // }
#
# async fetchData():Promise&lt;void&gt; {
#   const response:FacilityDTO[] =await this.facilityService.getFacilityOriginLocation();
#   if (response) {
#     this.facilityList = response.map((dto:FacilityDTO) =&gt; {
#   let facility=new Facility();
#
#   //filtering null data
#   if (dto==null) {
#   console.log(&quot;Encountered null data, Please check the database entry&quot;);
#   return;
#         }
#     facility.facilityAbbreviation=dto.facilityAbbreviation;
#     facility.facilityId=dto.facilityId;
#     facility.facilityNumber = dto.facilityNumber;
#     facility.name=dto.name;
#     facility.typeCode=dto.typeCode;
#
#   //pushing originLocation to locationArray
#   let OriginLocation=
#   dto.facilityAbbreviation+&quot;/&quot;+dto.facilityNumber;
#         this.locationArray.push(OriginLocation);
#
#   return facility;
#       });
#     }
#   }
#
#   vesselInputChange() {
#     this.tripLegIndexEmitter.emit(this.index);
#   }
#
#   removeTripLeg() {
#     this.deleteAtIndex.emit(this.index);
#   }
# }
# </code></pre>
# <p>trip-leg component.spec</p>
# <pre><code>describe('TripLegSectionComponent', () =&gt; {
#   let component: TripLegSectionComponent;
#   let fixture: ComponentFixture&lt;TripLegSectionComponent&gt;;
#   beforeEach(async(() =&gt; {
#
#     TestBed.configureTestingModule({
#       declarations: [TripLegSectionComponent, TripLegComponent],
#       imports: [
#         BrowserAnimationsModule,
#         ReactiveFormsModule,
#         HttpClientTestingModule,
#         MatAutocompleteModule,
#         MatFormFieldModule,
#         MatInputModule,
#         MatCardModule,
#         FormsModule
#       ],
#       schemas: [NO_ERRORS_SCHEMA],
#     })
#       .compileComponents();
#   }));
#
#   beforeEach(() =&gt; {
#     fixture = TestBed.createComponent(TripLegSectionComponent);
#     component = fixture.componentInstance;
#     component.schedule = new Schedule();
#     fixture.detectChanges();
#   });
#
#   it('should create', () =&gt; {
#     expect(component).toBeTruthy();
#   });
# it('should allow Larry to remove trip legs when there is more than 1', async () =&gt; {
#     const compiled = fixture.debugElement;
#     const testcompile = fixture.debugElement.nativeElement;
#
#     let scheduleWithTripLegList = new Schedule();
#     scheduleWithTripLegList.originId = 'origin';
#     scheduleWithTripLegList.destinationId = 'destination';
#     let tripLeg1 = new TripLeg();
#     tripLeg1.originId = '1';
#     tripLeg1.destinationId = '1';
#     tripLeg1.vesselType = '1';
#     tripLeg1.vesselStatus = '1';
#     tripLeg1.vesselLength = '1';
#     tripLeg1.vendor = '1';
#     let tripLeg2 = new TripLeg();
#     tripLeg2.originId = '2';
#     tripLeg2.destinationId = '2';
#     tripLeg2.vesselType = '2';
#     tripLeg2.vesselStatus = '2';
#     tripLeg2.vesselLength = '2';
#     tripLeg2.vendor = '2';
#     let tripLeg3 = new TripLeg();
#     tripLeg3.originId = '3';
#     tripLeg3.destinationId = '3';
#     tripLeg3.vesselType = '3';
#     tripLeg3.vesselStatus = '3';
#     tripLeg3.vesselLength = '3';
#     tripLeg3.vendor = '3';
#     scheduleWithTripLegList.tripLegs = [tripLeg1, tripLeg2, tripLeg3];
#
#     component.schedule = scheduleWithTripLegList;
#     fixture.detectChanges();
#
#     console.log(fixture);
#
#     await fixture.whenStable();
#     let removeTripButtons: DebugElement[] = compiled.queryAll(By.css('.remove-trip-leg-button'));
#     expect(removeTripButtons.length).toEqual(3);
#     let tripLegContainers: DebugElement[] = compiled.queryAll(By.css('.trip-leg-container'));
#     expect(tripLegContainers.length).toEqual(3);
#
#
#     //let firstTripOriginInput: DebugElement = compiled.queryAll(By.css('#trip-origin-input'))[0];
#     let firstTripOriginInput: DebugElement = testcompile.querySelector('input[ id =&quot;trip-origin-input&quot;]')[0];
#     expect(firstTripOriginInput.nativeElement.value).toEqual('1');
#     let secondTripOriginInput: DebugElement = compiled.queryAll(By.css('#trip-origin-input'))[1];
#     expect(secondTripOriginInput.nativeElement.value).toEqual('2');
#     let thirdTripOriginInput: DebugElement = compiled.queryAll(By.css('#trip-origin-input'))[2];
#     expect(thirdTripOriginInput.nativeElement.value).toEqual('3');
#
#     removeTripButtons[0].nativeElement.click();
#     fixture.detectChanges();
#
#     await fixture.whenStable();
#     removeTripButtons = compiled.queryAll(By.css('.remove-trip-leg-button'));
#     tripLegContainers = compiled.queryAll(By.css('.trip-leg-container'));
#     expect(removeTripButtons.length).toEqual(2);
#     expect(tripLegContainers.length).toEqual(2);
#
#     firstTripOriginInput = compiled.queryAll(By.css('#trip-origin-input'))[0];
#     expect(firstTripOriginInput.nativeElement.value).toEqual('2');
#     secondTripOriginInput = compiled.queryAll(By.css('#trip-origin-input'))[1];
#     expect(secondTripOriginInput.nativeElement.value).toEqual('3');
#   });
# </code></pre>
# <p>the problematic piece of code is from trip-leg component spec.ts file which is as following</p>
# <pre><code>    let firstTripOriginInput: DebugElement = compiled.queryAll(By.css('#trip-origin-input'))[0];
#     expect(firstTripOriginInput.nativeElement.value).toEqual('1');
# ...
#             BankCustomerRefundService objCustomerRefundService = new BankCustomerRefundService();
#             BankCustomerRefundService.BankCustomerRefundWrapper objRefundWrapper = new BankCustomerRefundService.BankCustomerRefundWrapper();
#             Id accountId = siInfo.Account__c;
#             objRefundWrapper.AccountId = accountId;
#             objRefundWrapper.PostingDate = Date.Today()+(-216);
#             objRefundWrapper.BankAccountId = bankId;
#             objRefundWrapper.TaxRate = taxRate;
#             objRefundWrapper.Amount = amount;
#             objRefundWrapper.Reference = reference;
#             BankCustomerRefundService.Response objResponse = objCustomerRefundService.CreateBankCustomerRefund(objRefundWrapper);
#             responseMessage = objResponse.ResponseMessage;
#
#             if(allocateToInvoice &amp;&amp; responseMessage == successMessage){
#                 Bank_Payment__c objBankPayment = objResponse.BankPayments.get(accountId);
#                 List&lt;Ledger__c&gt; listofLedgers = [Select id,name,Foreign_Gross_Total__c,Type__c
#                                                 FROM Ledger__c
#                                                 Where Customer_Supplier_Account_Name__c =: accountId AND Show_On_Transaction__c=1
#                                                 AND Paid__c = 'N' AND Is_Deleted__c = false
#                                                 AND (Sales_Invoice_Line_Item__c IN: mapOfSelectedLines.keyset() OR Bank_Payment__c =: objBankPayment.id) ];
#
#                 if(!listofLedgers.isEmpty()){
#                     BankAllocateCreditsAndPaymentsService objAllocateCreditsAndPaymentService = new BankAllocateCreditsAndPaymentsService();
#                     BankAllocateCreditsAndPaymentsService.BankAllocateCreditsAndPaymentsWrapper objAllocateCreditWrapper = new BankAllocateCreditsAndPaymentsService.BankAllocateCreditsAndPaymentsWrapper();
#                     objAllocateCreditWrapper.AccountId = accountId;
#                     objAllocateCreditWrapper.PostingDate = Date.Today()+(-216);
#                     List&lt;BankAllocateCreditsAndPaymentsService.BankAllocateCreditsAndPaymentsLineWrapper&gt; BankAllocateCreditsAndPaymentsLines = new List&lt;BankAllocateCreditsAndPaymentsService.BankAllocateCreditsAndPaymentsLineWrapper&gt;();
#                     for(Ledger__c ledger : listofLedgers){
#                         BankAllocateCreditsAndPaymentsService.BankAllocateCreditsAndPaymentsLineWrapper objPaymentLine = new BankAllocateCreditsAndPaymentsService.BankAllocateCreditsAndPaymentsLineWrapper();
#                         objPaymentLine.LedgerName = ledger.Name;
#                         objPaymentLine.Amount = ledger.Foreign_Gross_Total__c;
#                         BankAllocateCreditsAndPaymentsLines.add(objPaymentLine);
#                     }
#
#                     objAllocateCreditWrapper.BankAllocateLines = BankAllocateCreditsAndPaymentsLines;
#                     BankAllocateCreditsAndPaymentsService.Response objAllocateResponse = objAllocateCreditsAndPaymentService.BankAllocateCustomerBalance(objAllocateCreditWrapper);
#                     responseMessage = objAllocateResponse.ResponseMessage;
#                     system.debug('Response&gt;&gt;' + objAllocateResponse.ResponseMessage);
#                 }
#             }
#
#         }
#     }catch(Exception ex){
#         responseMessage = ex.getStackTraceString();
#     }
#
#     if(responseMessage != successMessage){
#         Database.rollback(spTran);
#     }
#     system.debug('Response&gt;&gt;' + responseMessage);
#     return responseMessage;
#
# }
# </code></pre>
#
#
# Display Name: Saad Ashraf
# Profile Image URL: https://www.gravatar.com/avatar/eb5d828cfc565a7a8645a987031169fc?s=128&d=identicon&r=PG&f=1
# Post ID: 63254234
# Post Body: <p>So right now I'm trying to build this radio list for the regions in LWC, the functionality works fine in that when you click on the regions it selects all the states below for that region.</p>
# <p><a href="https://i.stack.imgur.com/y2MM8.png" rel="nofollow noreferrer">https://i.stack.imgur.com/y2MM8.png</a></p>
# <p>However, I want to stylize it so that it looks more proper. I'm a little confused how to do this using these components that LWC provides. Here's a mockup of what the regions should look like.</p>
# <p><a href="https://i.stack.imgur.com/A26PH.png" rel="nofollow noreferrer">https://i.stack.imgur.com/A26PH.png</a></p>
# <p>Here's what the HTML for it looks like.</p>
# <p><a href="https://i.stack.imgur.com/1vWcy.png" rel="nofollow noreferrer">https://i.stack.imgur.com/1vWcy.png</a></p>
#
#
# Display Name: Somanden
# Profile Image URL: https://www.gravatar.com/avatar/d93bcd74931c7cd8fc7e7246e9dab318?s=128&d=identicon&r=PG&f=1
# Post ID: 63205581
# Post Body: <p>I have made a Blazor app, that authenticate users in my AzureAD, that works out of the box and are very smooth. Users are from different customers and are in a ADgroups for every customer, but use the same APP, and have roles from the App-setting in AzureAD.</p>
# <p>Problem:<br />
# The customers have their own SQL with data and users must only see data from their own Azure-SQL, so I have a long list of SQL databases, one for each customer. When I validate a user, I can only get the AD-group-GUID from tokens, so how do I differentiate the SQL databases, for every customer?</p>
# <p>My solution so far is to have a manually updated table with the customerID and AzureAD group GUID and use this to allow access to the users, to their data, but this seems to be a workaround.</p>
# <p>Can some of you think of a better solution to this problem, where users must only access one of N* databases, allowed from a AzureAD group?</p>
#
#
# Display Name: Gaurav Chaudhary
# Profile Image URL: https://lh6.googleusercontent.com/-LdtSZorvquw/AAAAAAAAAAI/AAAAAAAAAwg/NFbU2DLYCCs/photo.jpg?sz=128
# Post ID: 63224351
# Post Body: <p>I have problem deleting/updating cookie from asp.net C# side. Its working fine on older version but not on windows chrome 84.0.4147.105</p>
# <p>Code to delete cookie</p>
# <pre><code> HttpCookie Cookie = HttpContext.Current.Request.Cookies[cookieName];
#             if (Cookie != null)
#             {
#                 Cookie.Expires = DateTime.Now.AddDays(-2);
#                 HttpContext.Current.Response.Cookies.Add(Cookie);
#             }
# </code></pre>
# <p>I have tried adding cookie.secure - true, since this is .net framework version 4.5 i dont have samesite option available in framework or in web.config</p>
# <p>Tried IIS rewrite rule and its working. Cookie is both secure and samesite None but still the chromeis not deleting the cookie.</p>
# <pre><code>&lt;rule name=&quot;SessionCookieAddNoneHeader&quot;&gt;
#           &lt;match serverVariable=&quot;RESPONSE_Set-Cookie&quot; pattern=&quot;(.*ACUsername.*)&quot; /&gt;
#           &lt;!-- Use this regex if your OS/framework/app adds SameSite=Lax automatically to the end of the cookie --&gt;
#           &lt;!-- &lt;match serverVariable=&quot;RESPONSE_Set-Cookie&quot; pattern=&quot;((.*)(ASP.NET_SessionId)(=.*))(?=SameSite)&quot; /&gt; --&gt;
#           &lt;action type=&quot;Rewrite&quot; value=&quot;{R:1}; SameSite=None&quot; /&gt;
#         &lt;/rule&gt;
# </code></pre>
# <p>Please help if someone is facing the same issue with newer chrome version</p>
# <p>Thanks</p>
#
#
# Display Name: Francesco Iapicca
# Profile Image URL: https://i.stack.imgur.com/p2ehG.jpg?s=128&g=1
# Post ID: 63250005
# Post Body: <p>I guess the code below is more clear than any explaination</p>
# <p><a href="https://dartpad.dartlang.org/a5107762d7f5d564f0f20206ddbd48d1" rel="nofollow noreferrer">https://dartpad.dartlang.org/a5107762d7f5d564f0f20206ddbd48d1</a></p>
# <p>as for the title: is there a way to avoid calling &quot;super&quot; every time I extend a class?</p>
# <p>thank you</p>
#
#
# Display Name: Pixeel
# Profile Image URL: https://lh3.googleusercontent.com/a-/AOh14Gh1ZJ2Zo-I04GdhCw3lWMHMR1oNWr2U8YpOGcCyiA=k-s128
# Post ID: 63214920
# Post Body: <p>I am trying to get how many members a certain member has invited. The code below works, but it counts all invited members including members that have left.
# I want it to show only the amount of invited members which are still on the server.</p>
# <pre><code>var user = null;
# user = message.mentions.members.first() || message.author;
#
# message.guild.fetchInvites()
# .then(invites =&gt;
# {
#     const userInvites = invites.array().filter(o =&gt; o.inviter.id === user.id);
#     var userInviteCount = 0;
#
#     for(var i=0; i &lt; userInvites.length; i++)
#     {
#         var invite = userInvites[i];
#         userInviteCount += invite['uses'];
#         userInviteCount - invite['left'];
#     }
#
#     message.reply(`You have ${userInviteCount} invites.`);
# });
# </code></pre>
#
#
# Display Name: xuan
# Profile Image URL: https://lh3.googleusercontent.com/a-/AOh14GigO0OU1Sfce93c2gyLmtvF4PZkQ8rC09fy-BIYJnA=k-s128
# Post ID: 63250880
# Post Body: <p>I am learning WEKA, I want to increase the heap size.</p>
# <p>I did Q&amp;A researches, most of the answers showed that heap size can be changed in <strong>RunWeka.ini</strong>, but I couldn't find <strong>RunWeka.ini</strong> and also maxheap.</p>
# <p><strong>My WEKA version is Weka 3.8.4</strong>
# <img src="https://i.stack.imgur.com/kxTWW.png" alt="enter image description here" /></p>
#
#
# Display Name: JPV
# Profile Image URL: https://www.gravatar.com/avatar/bed8d007d46188649af0f2661c9360a6?s=128&d=identicon&r=PG&f=1
# Post ID: 63251481
# Post Body: <p>i am trying to add default arguments to a glue job on AWS CDK, specifically the bookmark option enabled. keep on getting the same error:</p>
# <p><code>Error: Resolution error: Supplied properties not correct for &quot;CfnJobProps&quot; defaultArguments: &quot;--job-bookmark-option: job-bookmark-enable&quot; should be an 'object'. </code></p>
# <p>my bode is below:</p>
# <pre><code>    glueETLJob = _glue.CfnJob(
#         self,
#         glueJobName,
#         command =_glue.CfnJob.JobCommandProperty(
#             name = glueJobName,
#             python_version= '3',
#             script_location = config_bucket_arn + &quot;/code/gluejob.py&quot;
#         ),
#         role=glueJobRole.role_arn,
#         glue_version='1.0',
#         max_retries=0,
#         timeout=30,
#         security_configuration=glueSecurityConfiguration.ref,
#         default_arguments=str(&quot;--job-bookmark-option: job-bookmark-enable&quot;),
#         description=&quot;glue job&quot;
#     )
# </code></pre>
#
#
# Display Name: Trts
# Profile Image URL: https://www.gravatar.com/avatar/adabf7f065858c050e95bb5f712b3092?s=128&d=identicon&r=PG
# Post ID: 63253017
# Post Body: <p>I am using Django 3.0.8.</p>
# <p><strong>settings.py</strong></p>
# <pre><code>INSTALLED_APPS = [
#     'admin_aux.apps.AdminAuxConfig', # PROJECT_APPS
# </code></pre>
# <p><strong>apps.py</strong></p>
# <pre><code>from django.apps import AppConfig
#
#
# class AdminAuxConfig(AppConfig):
#     name = 'admin_aux'
#
#     def ready(self):
#         import admin_aux.allauth_avatar # Breakpoint. Stopps here when the server is run.
# </code></pre>
# <p><strong>admin_aux/allauth_avatar.py</strong></p>
# <pre><code>@receiver(user_signed_up) # Breakpoint. Doesn't stop here when the server is run.
# def on_user_signed_up(sender, request, *args, **kwargs):
#     sociallogin = kwargs.get('sociallogin')
#     if sociallogin:
#         copy_avatar(request,
#                     sociallogin.account.user,
#                     sociallogin.account)
# </code></pre>
# <p>Problem: the receiver doesn't receive the signal.</p>
# <p>I marked breakpoints in the code.</p>
# <p>When I run debugging in PyCharm, I expect that the interpreter will stop at the breakpoint in allauth_avatar.py. But it doesn't. So, signal seems to be not connected. How can I resolve this?</p>
#
#
# Display Name: Jose Maria del Olmo
# Profile Image URL: https://lh3.googleusercontent.com/a-/AOh14Ggggjq8vCSSAnYgxo1UROzCIujKpwXQWA6L4adsTGo=k-s128
# Post ID: 63222719
# Post Body: <p>I have a group of print servers that I want to monitor from a database server, by collecting event log data into a table in my SQL Server database.</p>
# <p>I am writing a Powershell script to be scheduled on my database server, to get all printer servers data. I would prefer to avoid creation of temp files in <code>printservers</code> (and if possible in database server) to avoid cleaning up.</p>
# <p>I am running Powershell as admin and using the following code:</p>
# <pre><code>    $PrintServerName = &quot;usqasws0502.phx-dc.com&quot;
#     $sqlServer = &quot;CZCHOWSTC000583&quot;
#     $Database  = &quot;PrintMonitor&quot;
#     $USusername= &quot;User1&quot;
#     $USpassword= &quot;Passw1&quot;
#
#     $time = @{label='Time Printed'; Expression={get-date $_.TimeCreated -format s}}
#     $documentID = @{label='Document ID'; Expression={$_.properties[0].value}} ## Sample value are 181,182,...
#     $documentName = @{label='Document Name'; Expression={$_.properties[1].value}} ## Print Document Constante
#     $userID = @{label='User ID'; Expression={$_.properties[2].value}}  #srv_phxdc-cw1webprin
#     $computerID = @{label='Computer ID'; Expression={$_.properties[3].value}}  ##\\USQASWS0500
#     $printer = @{label='Printer'; Expression={$_.properties[4].value}}  ##CR-SJO-TSM-XER-LASER-CARGOWISE-AFR1-TSMOFFICE-XEROX
#     $sizeInBytes = @{label='Size in Bytes'; Expression={$_.properties[6].value}}  ## 270181
#     $numberOfPages = @{label='Number of Pages'; Expression={$_.properties[7].value}} ##2
#
#     $TmpFile = &quot;H:\CWData\Monitoring\Printers\tempfile.csv&quot;
#     $filter = @{ LogName =&quot;Microsoft-Windows-PrintService/Operational&quot;
#                  ID = 307
#                  StartTime = [DateTime]::Today.AddDays(-10)
#                  EndTime =   [DateTime]::Today
#                }
#      $Cred = New-Object PSCredential -ArgumentList @($USusername, ($USpassword|ConvertTo-SecureString -AsPlainText -Force))
#      $s = New-PSSession -ComputerName $PrintServerName -Credential $Cred
#      Invoke-Command -Session $s {
#      $event = Get-WinEvent -FilterHashtable @{LogName=&quot;Microsoft-Windows-PrintService/Operational&quot;; ID=307; StartTime = [DateTime]::Today.AddDays(-10); EndTime = [DateTime]::Today } -ErrorAction SilentlyContinue
#         |Sort TimeCreated -Descending |Format-Table -Wrap -AutoSize
# </code></pre>
# <p>#Line above displays an output like this</p>
# <blockquote>
# <p>TimeCreated            Id LevelDisplayName Message</p>
# </blockquote>
# <hr />
# <blockquote>
# <p>7/27/2020 5:40:32 PM  307 Information      Document 253, Print Document owned by SRV_PHXDC-CW1WEBPRIN on
# \USQASWS0502 was printed on US-LAX-LASER-USLAXNP2LASER13
# through port 7.233.205.205.  Size in bytes: 113367. Pages
# printed: 1. No user action is required.<br />
# 7/27/2020 5:40:24 PM  307 Information      Document 252, Print Document owned by SRV_PHXDC-CW1WEBPRIN on
# \USQASWS0502 was printed on US-LAX-LASER-USLAXNP2LASER13
# through port 7.233.205.205.  Size in bytes: 120234. Pages
# printed: 2. No user action is required.</p>
# </blockquote>
# <pre><code>    $obj= $event |select $time, $documentID, $documentName,$userID, $computerID, $printer, $printerPort, $sizeInBytes, $numberOfPages | export-csv &quot;H:\CWData\Monitoring\Printers\PrintLog_$ServerName_tempfile.csv&quot;
#     #The line above  generates an empty file..
#     Write-SQLTableData -TableName PrintService-Job -SchemaName dbo -DatabaseName $Database -ServerInstance $sqlServer -InputData  $obj
#     #The line above does not enter anything in the DB generates an empty file..
# </code></pre>
# <p>My database table would be:</p>
# <pre><code>CREATE TABLE [dbo].[PrintService-Job]
# (
#       [pj_id] [int] IDENTITY(1,1) NOT NULL,
#       [pj_DateTime] [varchar](50) NULL,
#       [pj_PrintServer] [varchar](50) NULL,
#       [pj_PrintClient] [varchar](50) NULL,
#       [pj_PrinterName] [varchar](50) NULL,
#       [pj_SizeBytes] [varchar](50) NULL
# )
# </code></pre>
# <p>Can you guide me what I am doing wrong? (or point me to a script that transfer data from Windows event logs to SQL Server database tables)</p>
